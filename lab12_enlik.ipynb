# %% [markdown]
# <h1><center> <font color='black'> Business Data Analytics - Practice Session_12 </font></center></h1>
# <h2><center> <font color='black'>  Knowledge Graphs (KG)</font></center></h3>
# <h2><center> <font color='black'> University of Tartu - Spring 2020</font></center></h3>

# %%
from IPython.display import Image
Image(filename='wiki.png')

# %% [markdown]
# ## Introduction
#
# * **Finance wkiki** has quite a lot of information there! We have `text`, `tons of hyperlinks`, and even an `audio clip`. That’s a lot of relevant and potentially useful information on a single page. The possibilities of putting this into a use case are endless.
#
# * However, there is a slight problem. This is not an ideal source of data to feed to our machines. Not in its current form anyway.
#
# * Can we find a way to make this text data readable for machines? Essentially, **can we transform this text data into something that can be used by the machines and also can be interpreted easily by us?**

# %% [markdown]
# * **Yes, we can!** We can do it with the help of **Knowledge Graphs (KG)**, one of the most fascinating concepts in data science.
#
#
#
# ## Table of Contents
#
# * What is a Knowledge Graph?
# * How to Represent Knowledge in a Graph?
#     * Sentence Segmentation
#     * Entities Extraction
#     * Relations Extraction
# * Build a Knowledge Graph from Text Data
# * Clustering and Classification using Knowledge Graph Embeddings

# %% [markdown]
# ### What is a Knowledge Graph?
#
# * Let’s get one thing out of the way – we will see the term **graphs** a lot in this article. We do not mean bar charts, pie charts, and line plots when I say graphs. Here, **we are talking about interconnected `entities` which can be people, locations, organizations, or even an event.**
#
# * We can define a `graph` as a set of **nodes** and **edges.**

# %%
Image(filename='lab.png')

# %% [markdown]
# * Node **A** and Node **B** here are two different `entities`. These nodes are connected by an **edge** that represents the `relationship` between the two nodes. Now, this is the smallest knowledge graph we can build – it is also known as a `triple.`
#
# * Knowledge Graph’s come in a variety of shapes and sizes. For example, the knowledge graph of Wikidata had 59,910,568 nodes by October 2019.

# %% [markdown]
# ### How to Represent Knowledge in a Graph?
#
# * Before we get started with building Knowledge Graphs, it is important to understand how information or knowledge is `embedded` in these graphs.
#
# * Let me explain this using an example. If `Node A = Putin` and `Node B = Russia`, then it is quite likely that the `edge would be “president of”:`

# %%
Image(filename='lab2.png')

# %% [markdown]
# * **A node or an entity** can have multiple relations as well. Putin is not only the President of Russia, he also worked for the `Soviet Union’s security agency, KGB.` But how do we incorporate this new information about Putin in the knowledge graph above?
#
# * It’s actually pretty simple. `Just add one more node` for the new entity, KGB:

# %%
Image(filename='lab3.png')

# %% [markdown]
# * The new relationships can emerge not only from the first node but from any node in a knowledge graph as shown below:

# %% [markdown]
# * Identifying the entities and the relation between them is not a difficult task for us. However, `manually building a knowledge graph is not scalable.` Nobody is going to go through thousands of documents and extract all the entities and the relations between them!
#
# * That’s why machines are more suitable to perform this task as going through even hundreds or thousands of documents is child’s play for them. But then there is another challenge – machines do not understand `natural language.` This is where **Natural Language Processing (NLP)** comes into the picture.
#
# * To build a knowledge graph from the `text,` it is important to make our machine understand natural language. This can be done by using NLP techniques such as `sentence segmentation, dependency parsing, parts of speech tagging, and entity recognition.` Let’s discuss these in a bit more detail.

# %% [markdown]
# ### Sentence Segmentation
#
# * The first step in building a knowledge graph is `to split the text document or article into sentences.` Then, we will shortlist only those sentences in which there is exactly `1 subject and 1 object.` Let’s look at a sample text below:
#
# “Indian tennis player Sumit Nagal moved up six places from 135 to a career-best 129 in the latest men’s singles ranking. The 22-year-old recently won the ATP Challenger tournament. He made his Grand Slam debut against Federer in the 2019 US Open. Nagal won the first set.”
#
# * Let’s split the paragraph above into sentences:
#
#     * Indian tennis player Sumit Nagal moved up six places from 135 to a career-best 129 in the latest men’s singles ranking
#     * The 22-year-old recently won the ATP Challenger tournament
#     * He made his Grand Slam debut against Federer in the 2019 US Open
#     * Nagal won the first set
#
# * Out of these four sentences, `we will shortlist the second and the fourth sentences` because each of them contains `1 subject and 1 object.` In the second sentence, **22-year-old** is the subject and the object is **ATP Challenger tournament**. In the fourth sentence, the subject is **Nagal** and **first set** is the object:

# %%
Image(filename='lab4.png')

# %% [markdown]
# ### Entities (nodes) Extraction
#
# * The extraction of a single word entity from a sentence is not a tough task. We can easily do this with the help of `parts of speech (POS) tags.` The `nouns and the proper nouns would be our entities.`
#
# * However, when an entity spans across multiple words, then POS tags alone are not sufficient. We need to parse the dependency tree of the sentence. You can read more about dependency parsing in the following article.
#
#     * Introduction to Information Extraction using Python and spaCy
#
# * Let’s get the dependency tags for one of the shortlisted sentences. we will use the popular spaCy library for this task:

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
import spacy

# nlp 
import en_core_web_sm
nlp = en_core_web_sm.load()
# nlp = spacy.load('en_core_web_sm')

# corpus
doc = nlp("The 22-year-old recently won ATP Challenger tournament.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# The ... det
# 22-year ... npadvmod
# - ... punct
# old ... nsubj
# recently ... advmod
# won ... ROOT
# ATP ... compound
# Challenger ... compound
# tournament ... dobj
# . ... punct

# %% [markdown]
#  * The subject **(nsubj)** in this sentence as per the dependency parser is `old`. That is not the desired entity. We wanted to extract `22-year-old` instead.
#
# * The dependency tag of `22-year` is **amod** which means it is `a modifier` of `old`. Hence, we should define a rule to extract such entities.
#
#
# * The rule can be something like this — `extract the subject/object along with its modifiers and also extract the punctuation marks between them.`
#
#
# * But then look at the object `(dobj)` in the sentence. It is just **tournament** instead of **ATP Challenger tournament**. Here, we don’t have the modifiers but compound words.
#
#
# * **Compound words** are those words that collectively form a new term with a different meaning. Therefore, we can update the above rule to ⁠— `extract the subject/object along with its modifiers, compound words and also extract the punctuation marks between them.`
#
#
# * In short, we will use `dependency parsing` to extract entities.

# %% [markdown]
# ### Extract Relations
#
# * Entity extraction is half the job done. To build a knowledge graph, we need `edges` to connect the nodes (entities) to one another. `These edges are the relations between a pair of nodes.`
#
#
# * Let’s go back to the example in the last section. We shortlisted a couple of sentences to build a knowledge graph:

# %%
Image(filename='lab5.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-75b0ee4e08cc> in <module>
# ----> 1 Image(filename='lab5.png')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# * Can you guess the relation between the `subject and the object` in these two sentences?
#
# * Both sentences have the same relation – **won**. Let’s see how these relations can be extracted. We will again use dependency parsing:

# %%
doc = nlp("Nagal won the first set.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Nagal ... nsubj
# won ... ROOT
# the ... det
# first ... amod
# set ... dobj
# . ... punct

# %% [markdown]
# * **To extract the relation,** we have to find the `ROOT` of the sentence (which is also the `verb` of the sentence). Hence, the relation extracted from this sentence would be **won**.
#
# * Finally, the knowledge graph from these two sentences will be like this:

# %%
Image(filename='lab6.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6e56bf9354ab> in <module>
# ----> 1 Image(filename='lab6.png')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### Build a Knowledge Graph from Text Data
#
# * We will build a `knowledge graph` from scratch by using the `text from a set of movies and films related to Wikipedia articles.` Each of these sentences contains exactly `two entities – one subject and one object.`

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %% [markdown]
# #### Read Data

# %%
# Read the CSV file containing the Wikipedia sentences:
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
# Out:
# (4318, 1)

# %%
# Let’s inspect a few sample sentences
candidate_sentences['sentence'].sample(5)
# Out:
# 2670                          other locations include st.
# 2064    the fox fanfare was also re-orchestrated in 1981.
# 1023                     — in mulholland falls , and l.a.
# 676          only one film is accepted from each country.
# 183       fletcher received an executive producer credit.
# Name: sentence, dtype: object

# %%
# define our document
doc = nlp("the drawdown process is governed by astm standard d823")

# extract tokens from doc
for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... amod
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... amod
# d823 ... pobj

# %% [markdown]
# * Perfect! There is only one subject `(process)` and only one object `(standard)`. You can check for other sentences in a similar manner.

# %% [markdown]
# #### Entity Pairs Extraction
#
#
# * To build a knowledge graph, the most important things are the nodes and the edges between them.
#
#
# * These nodes are going to be the `entities` that are present in the Wikipedia sentences. `Edges` are the relationships connecting these entities to one another. We will extract these elements in an unsupervised manner, i.e., we will use the `grammar of the sentences.`
#
#
# * The main idea is to go through a sentence and extract the subject and the object as and when they are encountered.
#
# * So, we have created a function below to `extract the subject and the object (entities)` from a sentence

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %% [markdown]
# * Let me explain the code chunks in the function above:
#
# 1. Chunk 1:
#     * we defined a few empty variables in this chunk. `prv_tok_dep` and `prv_tok_text` will hold the `dependency tag` of the previous word in the sentence and that previous word itself, respectively. `prefix and modifier` will hold the text that is associated with the `subject or the object.`
#
# 2. Chunk 2:
#     * Next, we will loop through the tokens in the sentence. We will first check if the token is a punctuation mark or not. If yes, then we will ignore it and move on to the next token. If the token is a part of a compound word (dependency tag = “compound”), we will keep it in the prefix variable. A compound word is a combination of multiple words linked to form a word with a new meaning (example – “Football Stadium”, “animal lover”).
#
#     * As and when we come across a subject or an object in the sentence, we will add this prefix to it. We will do the same thing with the modifier words, such as “nice shirt”, “big house”, etc.
#
# 3. Chunk 3:
#     * Here, if the token is the subject, then it will be captured as the first entity in the ent1 variable. Variables such as prefix, modifier, prv_tok_dep, and prv_tok_text will be reset.
#
# 4. Chunk 4:
#     * Here, if the token is the object, then it will be captured as the second entity in the ent2 variable. Variables such as prefix, modifier, prv_tok_dep, and prv_tok_text will again be reset.
#
# 5. Chunk 5:
#     *Once we have captured the subject and the object in the sentence, we will update the previous token and its dependency tag.
#
#
# * Let’s test this function on a sentence:

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %% [markdown]
# * Great, it seems to be working as planned. In the above sentence, `film` is the subject and `200 patents` is the object.
#
# * Now we can use this function to extract these entity pairs for all the sentences in our data:

# %%
candidate_sentences
# Out:
#                                                                                                       sentence
# 0                                                 confused and frustrated, connie decides to leave on her own.
# 1                                                            later, a woman’s scream is heard in the distance.
# 2                                                                     christian is then paralyzed by an elder.
# 3                                                                                   the temple is set on fire.
# 4                                                                            outside, the cult wails with him.
# ...                                                                                                        ...
# 4313     confidencial also responded negatively, calling the film a barren drama, unsubtle and self-indulgent.
# 4314                                             and le parisien gave the film their highest five-star rating.
# 4315  the museum collection includes 37,000 film titles, 60,000 posters, 700,000 photographs and 20,000 books.
# 4316                                   its predecessor was the dutch historical film archive, founded in 1946.
# 4317                                                         , 1920'sfilmstar greta garbo by alexander binder,
#
# [4318 rows x 1 columns]

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentence"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 4318/4318 [00:59<00:00, 72.39it/s]

# %% [markdown]
# * The list entity_pairs contains all the subject-object pairs from the Wikipedia sentences. Let’s have a look at a few of them:

# %%
entity_pairs[10:20]
# Out:
# [['we', 'tests'],
#  ['m global', 'international sales rights'],
#  ['robbie robertson', 'soundtrack'],
#  ['it', 'original music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['', 'military  arrest'],
#  ['train', 'vuk'],
#  ['telepath', 'gallio'],
#  ['singer', 'men']]

# %% [markdown]
# * As you can see, there are a few pronouns in these entity pairs such as `we`, `it`, `she`, etc. We’d like to have proper nouns or nouns instead. Perhaps we can further improve the get_entities( ) function to filter out pronouns. For the time being, let’s leave it as it is and move on to the relation extraction part.
#
#
# #### Relation / Predicate Extraction
#
# * This is going to be a very interesting aspect of this article. Our hypothesis is that the predicate is actually the main verb in a sentence.
#
# * For example, in the sentence – `Sixty Hollywood musicals were released in 1929`, the verb is `released in` and this is what we are going to use as the predicate for the triple generated from this sentence.
#
# * The function below is capable of capturing such predicates from the sentences. Here, we have used spaCy’s rule-based matching:

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", None, pattern) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %% [markdown]
# * The pattern defined in the function tries to find the ROOT word or the main verb in the sentence. Once the ROOT is identified, then the pattern checks whether it is followed by a preposition (‘prep’) or an agent word. If yes, then it is added to the ROOT word.
#
# * Let me show you a glimpse of this function:

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
# Out:
# 100%|██████████| 4318/4318 [01:08<00:00, 63.29it/s]

# %% [markdown]
# Let’s take a look at the most frequent relations or predicates that we have just extracted:

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# is               370
# was              297
# released on       87
# include           73
# were              71
# are               71
# released          40
# 's                38
# composed by       35
# have              31
# became            31
# has               31
# become            29
# released in       27
# included          26
# produced          22
# called            22
# considered        20
# made              20
# had               20
# be                18
# been              18
# scheduled         17
# used              17
# stars             16
# directed by       16
# written by        15
# hired             14
# set               14
# produced by       14
# wrote             14
# received          13
# went              13
# introduced in     13
# wanted            12
# began             11
# won               11
# began in          11
# sold              10
# features          10
# gave              10
# produced in        9
# gives              9
# used in            9
# includes           9
# shot in            9
# reported           9
# directed           9
# known as           9
# opened             9
# dtype: int64

# %% [markdown]
# * It turns out that relations like `A is B` and `A was B` are the most common relations. However, there are quite a few relations that are more associated with the overall theme – “the ecosystem around movies”. Some of the examples are `composed by`, `released in`, `produced`, `written by` and a few more.
#
#
# #### Build a Knowledge Graph
#
# * We will finally create a knowledge graph from the extracted entities `(subject-object pairs)` and the `predicates` (relation between entities).
#
# * Let’s create a `dataframe of entities and predicates:`

# %%
entity_pairs
# Out:
# [['connie', 'own'],
#  ['later  woman', 'distance'],
#  ['christian', 'then  elder'],
#  ['temple', 'fire'],
#  ['outside  cult', 'him'],
#  ['it', 'religious  awakening'],
#  ['c. mackenzie', 'craig cast'],
#  ['later craig di francia', 'action cast'],
#  ['sebastian  maniscalco', 'later paul ben cast'],
#  ['we', 'just  film'],
#  ['we', 'tests'],
#  ['m global', 'international sales rights'],
#  ['robbie robertson', 'soundtrack'],
#  ['it', 'original music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['', 'military  arrest'],
#  ['train', 'vuk'],
#  ['telepath', 'gallio'],
#  ['singer', 'men'],
#  ['last  which', 'penn'],
#  ['jessica chastain', 'same  character'],
#  ['mauro fiore', 'cinematographer'],
#  ['filming', 'october'],
#  ['soundtrack', 'digitally  june'],
#  ['album', 'digitally  august'],
#  ['film', 'studios motion pictures'],
#  ['it', '$  103.7'],
#  ['', ''],
#  ['it', 'executive producer yoshimitsu banno'],
#  ['vivienne graham', 'former employee dr'],
#  ['emma monster which', 'several monarch dr'],
#  ['madison', 'mythological  texts'],
#  ['joe morton', 'older  dr'],
#  ['godzilla', 'king themselves'],
#  ['when  dougherty', 'when  reaction'],
#  ['we', 'godzilla'],
#  ['only  mandate', 'monarch'],
#  ['ten  writers', 'treatment'],
#  ['script', 'year'],
#  ['dougherty', ''],
#  ['film', 'this'],
#  ['it', 'big  dinosaurs'],
#  ['other  actors', 'body'],
#  ['designer scott chambliss', 'art directors'],
#  ['single', 'may'],
#  ['tracks', 'bear mccreary'],
#  ['score', 'also  mccreary'],
#  ['first teaser poster', 'december'],
#  ['theatrical  poster', 'april'],
#  ['film', 'originally  june'],
#  ['collectible  tickets', 'two  sizes'],
#  ['4k release', 'hdr10'],
#  ['retail  exclusives', 'clear  files'],
#  ['such  heroes', 'one  liners'],
#  ['it', 'science fiction twist'],
#  ['currently action films', 'extensive stunt work'],
#  ['examples', 'indiana jones franchise'],
#  ['themes', 'typical action horror films'],
#  ['mall cop', 'recent  trend'],
#  ['they', 'often entertainment storytelling'],
#  ['both', 'many  roles'],
#  ['producer', 'also  production'],
#  ['finally  producer', 'marketing'],
#  ['line producer', 'certain  cases'],
#  ['most  producers', 'college film school'],
#  ['film directors', 'screenwriters'],
#  ['other film directors', 'film school'],
#  ['directors', 'different  approaches'],
#  ['directors', 'additional  roles'],
#  ['film schools', 'sound  stages'],
#  ['full degree course', 'five  studying'],
#  ['film academy berlin', 'berlin tv station rbb'],
#  ['', 'la paris'],
#  ['national film awards', 'prominent film award india'],
#  ['awards', 'first  1954'],
#  ['national film awards', 'main  categories'],
#  ['he', 'home  apartment'],
#  ['mass riot', 'gotham'],
#  ['arthur', 'arkham state hospital'],
#  ['film war dogs', 'august'],
#  ['we', 'even  joker'],
#  ['then  we', 'that'],
#  ['pereira olson pereira hodge', 'cast'],
#  ['it', 'theatrically warner bros'],
#  ['it', 'eye  me'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['i', 'it'],
#  ['they', 'it'],
#  ['film', 'short samuel beckett'],
#  ['40-leaf shooting script', '22  may'],
#  ['beckett', 'zero alan mostel'],
#  ['beckett', 'then buster keaton'],
#  ['this', 'only united states'],
#  ['david rayner clark', 'max wall'],
#  ['suddenly  camera', 'violently  left'],
#  ['couple', 'other'],
#  ['camera', 'vestibule'],
#  ['camera', 'brief close up'],
#  ['she', 'slowly  feet'],
#  ['she', 'eyes'],
#  ['coat', 'stairs'],
#  ['simply  mechanics', 'tasks'],
#  ['he', 'them'],
#  ['he', 'still eye patch'],
#  ['he', 'half  chair'],
#  ['est percipi aut', ''],
#  ['he', 'away  himself'],
#  ['e', 'merely  person'],
#  ['e', ''],
#  ['script', 'various  ways'],
#  ['work', ''],
#  ['particular  beckett', 'particular  project'],
#  ['four  directors', 'series'],
#  ['he', 'book'],
#  ['david heyman', 'film'],
#  ['acting  experience', 'school plays'],
#  ['barron', 'four  films'],
#  ['executive  producers', 'tanya seghatchian tanya wigram'],
#  ['he', 'real  passion'],
#  ['directors', 'other'],
#  ['production designer', 'eight  films'],
#  ['so  we', 'substantial  piece'],
#  ['harry potter series', 'four  composers'],
#  ['desplat', 'harry potter'],
#  ['', '2  2011'],
#  ['they', 'trumps'],
#  ['shouts', 'last  time'],
#  ['harry potter', 'orphaned unkind aunt'],
#  ['however  part', '2  2d'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer', 'director'],
#  ['', 'bruce wayne barry allen'],
#  ['justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['villain mister mind', 'credits  scene'],
#  ['month  sequel', 'san diego comic con'],
#  ['production', 'early  december'],
#  ['month pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros'],
#  ['wonder woman', '1984  june'],
#  ['initial  script', 'berlanti'],
#  ['dan mazeau', 'writer'],
#  ['2018 john francis daley', 'march'],
#  ['plot', 'speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['producer peter who', 'emmerich'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad', 'shortly batman v superman'],
#  ['2017  johns', 'january'],
#  ['principal  photography', 'august'],
#  ['david ayer', 'director'],
#  ['', 'bruce wayne barry allen'],
#  ['justice league', 'worldwide  november'],
#  ['aquaman', 'october'],
#  ['production', 'august'],
#  ['villain mister mind', 'credits  scene'],
#  ['month  sequel', 'san diego comic con'],
#  ['production', 'early  december'],
#  ['month pedro pascal', 'key  role'],
#  ['filming  locations', 'warner bros'],
#  ['wonder woman', '1984  june'],
#  ['initial  script', 'berlanti'],
#  ['dan mazeau', 'writer'],
#  ['2018 john francis daley', 'march'],
#  ['plot', 'speed force multiverse'],
#  ['production', 'january'],
#  ['flash', 'sometime  2021'],
#  ['producer peter who', 'emmerich'],
#  ['production', '2020'],
#  ['aquaman', '2  december'],
#  ['suicide squad', 'shortly batman v superman'],
#  ['jim', 'two freddie kiss'],
#  ['they', 'last minute slot'],
#  ['2011  production', 'april'],
#  ['whishaw', 'project'],
#  ['i', 'man'],
#  ['discussions', 'him'],
#  ['fletcher', 'executive producer credit'],
#  ['vinyl release', '8  february'],
#  ['digital  version', '22  january'],
#  ['instead  it', 'threatening  illness'],
#  ['it', 'outside north america'],
#  ['new  markets', 'france'],
#  ['it', 'ever south korea'],
#  ['they', 'conclusions'],
#  ['horror', 'also  fantasy'],
#  ['prevalent elements', 'ghosts'],
#  ['it', 'third faust legend'],
#  ['this', 'trick films'],
#  ['trick films', 'special  effects'],
#  ["l'inferno", 'three  artists'],
#  ['series', 'close surrealist movement'],
#  ['film', 'five  stories'],
#  ['it', 'german  expressionism'],
#  ['f. w. murnau', 'themed  movie'],
#  ['it', 'gothic horror novel dracula'],
#  ['this', 'expressionism style'],
#  ['they', 'german expressionist movement'],
#  ['exaggerated  smile', 'dc joker'],
#  ['film', 'poorly  audiences'],
#  ['silent  classic', 'special morality effects'],
#  ['it', 'earlier  film'],
#  ['film', 'well  critics'],
#  ['assistant', 'abnormal  brain'],
#  ['first  one', 'rue morgue'],
#  ['it', 'boris karloff'],
#  ['first  one', 'july'],
#  ['it', 'blue murder mystery room'],
#  ['it', 'boris karloff'],
#  ['it', 'six  movies'],
#  ['universal  pictures', 'iconic  actors'],
#  ['peter ruric', 'screenplay'],
#  ['fiction horror film', '1931 hit frankenstein'],
#  ['actress elsa lanchester', 'bride'],
#  ['he', 'writing'],
#  ['radiation effects', 'slowly  him'],
#  ['film', 'title role'],
#  ['intervening  criticism', 'intervening  decades'],
#  ['film', 'boris karloff'],
#  ['phantom  creeps', 'universal 112th sound'],
#  ['other  studios', 'lead'],
#  ['fright  factor', 'way'],
#  ['film director', 'film gimmick'],
#  ['1950s', 'well creature feature'],
#  ['fly', 'american vincent price'],
#  ['film', 'popular cult culture'],
#  ['phrase', 'surreal twilight experiences'],
#  ['1970s', 'american horror films'],
#  ['', 'italian nicolas roeg'],
#  ['murder', 'main horror films'],
#  ['poltergeist', 'ever film critics association'],
#  ['changeling', 'psychological peter medak'],
#  ['influence', 'still  films'],
#  ['bloody  valentine', 'day fiction'],
#  ['rattle', 'philippines'],
#  ['several action horror movies', '1980s'],
#  ['dark fantasy horror which', 'special artist stan winston'],
#  ['event horizon', 'american fiction horror paul'],
#  ['monster horror', 'quite  1990s'],
#  ['tremors', 'first tremors franchise'],
#  ['valentine', 'contrast'],
#  ['others', 'many  awards'],
#  ['it', 'alejandro amenábar'],
#  ['comic book adaptations', 'blade series'],
#  ['pronounced  trends', 'horror films'],
#  ['films', 'english language countries'],
#  ['notable  film', 'spanish debut filmmaker'],
#  ['cold  prey', 'norwegian roar uthaug'],
#  ['others', 'psychological horror film'],
#  ['latter  film', 'sequel'],
#  ['', 'extraterrestrial  themes'],
#  ['verónica', 'real horror events'],
#  ['sequel', 'happy death february'],
#  ['themes', 'typical action horror films'],
#  ['category', 'also fantasy genre'],
#  ['horror which', 'holiday  season'],
#  ['it', 'christmas'],
#  ['examples', 'all r house'],
#  ['examples', 'frankenstein'],
#  ['common  themes', 'vengeful  ghosts'],
#  ['examples', 'ring'],
#  ['genre', 'sometimes science fiction'],
#  ['examples', 'birds'],
#  ['it', 'most  1964'],
#  ['examples', 'unfriended friend request'],
#  ['one', 'noticeable side effects'],
#  ['early horror films', 'social  controversy'],
#  ['however horror movies', 'positive  endings'],
#  ['satirical comedy drama', 'illicit love affair'],
#  ['others', 'duck soup'],
#  ['such  films', 'portmanteau words splatter'],
#  ['military  comedies', 'good  morning'],
#  ['film', 'thin  coating'],
#  ['today  it', 'international film commerce'],
#  ['it', 'simple  friends'],
#  ['1968  festival', '19  may'],
#  ['thierry frémaux', '2007'],
#  ['festival', 'european  films'],
#  ['jill forbes', 'european sarah cinema'],
#  ['however  curse', 'black  pearl'],
#  ['second  film', 'generated disney pictures logo'],
#  ['village roadshow studios', 'officially port locations'],
#  ['suddenly  market', 'musicals'],
#  ['many  comedies', 'musical  numbers'],
#  ['however sequel grease', '2 box office'],
#  ['chicago', 'first  oliver'],
#  ['original  ones', 'universe'],
#  ['musical  films', 'rio'],
#  ['indian sound film', ''],
#  ['however  colour', 'late  1950s'],
#  ['', 'raja hona'],
#  ['biggest bollywood movie stars', '1990s'],
#  ['juvenile  stars', 'box office'],
#  ['american  films', 'greatly  aleksandrov'],
#  ['successful  blend', 'social  message'],
#  ['another', 'popular  films'],
#  ['music', 'singing'],
#  ['here  work', 'spectacle'],
#  ['other  director', 'musical  films'],
#  ['all', 'wife'],
#  ['it', 'most  type'],
#  ['short', 'term'],
#  ['they', 'usually film grants'],
#  ['individual', ''],
#  ['griffith', 'nation'],
#  ['short  comedies', 'typically  serial'],
#  ['animated  cartoons', 'short  subjects'],
#  ['short  films', 'student  work'],
#  ['they', 'also  period'],
#  ['animated  shorts', 'commercial  distribution'],
#  ['shortstv', 'short television films'],
#  ['such  movies', 'also  internet'],
#  ['it', 'second it film series'],
#  ['juno rinaldi', 'adult gretta'],
#  ['ideally  we', 'march'],
#  ['part  one', 'only  kids'],
#  ['sophia lillis', 'jessica chastain'],
#  ['town hall exterior', 'derry library'],
#  ['visual  effects', 'atomic  arts'],
#  ['music', 'benjamin wallfisch'],
#  ['it', ''],
#  ['it', 'second it film series'],
#  ['juno rinaldi', 'adult gretta'],
#  ['ideally  we', 'march'],
#  ['part  one', 'only  kids'],
#  ['sophia lillis', 'jessica chastain'],
#  ['town hall exterior', 'derry library'],
#  ['visual  effects', 'atomic  arts'],
#  ['music', 'benjamin wallfisch'],
#  ['it', ''],
#  ['long feature film', 'time'],
#  ['narrative feature film', 'kelly gang'],
#  ['early  features', 'noteworthy style events'],
#  ['italian  features', 'days quo pompeii'],
#  ['1913', 'first feature film'],
#  ['songs', 'edgar yip harburg'],
#  ['musical  score', 'incidental  stothart'],
#  ['h. cannon', 'four page outline'],
#  ['part', 'betty  jaynes'],
#  ['instead contract player', 'frank september'],
#  ['gale sondergaard', 'wicked  witch'],
#  ['replacement', 'him'],
#  ['oz  sequences', 'three strip technicolor'],
#  ['arnold gillespie', 'special effects film'],
#  ['develop', 'tornado scene'],
#  ['house', 'small  maquete'],
#  ['cowardly  costume', 'real lion skin'],
#  ['film', 'musical  selections'],
#  ['haley', 'solo  parts'],
#  ['musical  pieces', 'editing process'],
#  ['this', 'ding dong'],
#  ['witch', 'smaller dialogue sequences'],
#  ['first sneak preview', 'san bernardino'],
#  ['film', 'nationwide  august'],
#  ['it', 'warner bros'],
#  ['restoration job', 'focus  world'],
#  ['film', 'ultra hd'],
#  ['2d version', 'still g rating'],
#  ['so  fantastic', 'half'],
#  ['film daily', ''],
#  ['major  differences', 'original  book'],
#  ['it', 'james franco'],
#  ['it', 'critical  reception'],
#  ['adrian', 'final costume design'],
#  ['film version', '1982'],
#  ['example', 'police story'],
#  ['genre', 'mehboob aurat'],
#  ['other  examples', 'gunga  jumna'],
#  ['they', 'honor killings'],
#  ['examples', 'angry  men'],
#  ['it', 'revalina sayuthi temat'],
#  ['rika', 'muslim actor surya'],
#  ['meanwhile  surya', 'affections'],
#  ['individual  characters', 'people bramantyo'],
#  ['film', 'rp 5 billion'],
#  ['bramantyo', 'main cast members'],
#  ['made movie musicals', 'made  tv'],
#  ['it', 'movie'],
#  ['principal  photography', 'june'],
#  ['first  trailer', 'day  november'],
#  ['final  trailer', 'march'],
#  ['north maleficent', 'north america'],
#  ['largest opening weekends', 'china'],
#  ['film', 'double  amount'],
#  ['everyone', 'even  presence'],
#  ['it', 'agency'],
#  ['it', 'power'],
#  ['we', 'very  rape'],
#  ['principal  photography', 'august'],
#  ['director godfrey reggio', 'composer philip music'],
#  ['artistic  merits', 'film music'],
#  ['production music', 'convenient media producers'],
#  ['apm', '250,000 us tracks'],
#  ['she', 'strength'],
#  ['where garland stops', 'zellweger film'],
#  ['she', 'tear'],
#  ['examples', 'killers'],
#  ['smith  this', 'war'],
#  ['title', 'cynical  image'],
#  ['', 'unfortunately  .'],
#  ['we', 'seriously  release'],
#  ['film', 'temporarily  brazil'],
#  ['2012  decision', '5  july'],
#  ['dragan bjelogrlić', 'film'],
#  ['that', 'something'],
#  ['i', 'it'],
#  ['you', 'serbian  film'],
#  ['i', 'conscience'],
#  ['nota', 'political anand shankar'],
#  ['film', 'box office'],
#  ['', 'video game uk'],
#  ['he', 'house arrest'],
#  ['varun', 'then  rowdy'],
#  ['day  she', '23 sleeping pills'],
#  ['dam', 'many  lives'],
#  ['vinothan', 'heated  argument'],
#  ['emotional  drama', 'characters'],
#  ['film', 'box office'],
#  ['i', 'indian s. shankar'],
#  ['soundtrack  score', 'a. r. rahman'],
#  ['production design', 't. muthuraj'],
#  ['principal  photography', '15  july'],
#  ['main  ambition', 'chennai'],
#  ['he', 'diya'],
#  ['well  lingesan', 'diya'],
#  ['diya', 'soon  truth'],
#  ['he', 'instead  her'],
#  ['eventually body he', 'face'],
#  ['he', 'then  them'],
#  ['they', 'secluded  life'],
#  ['additional stunt direction', 'anl  arasu'],
#  ['prosthetic  makeup', 'christien tinsley'],
#  ['later  name', 'chopra'],
#  ['film', '14  january'],
#  ['she', 'experience'],
#  ['media rights', 'satellite rights'],
#  ['net  collections', '240  crores'],
#  ['karma', '2015 kanittha kwanyu'],
#  ['atlee kumar', 'tamil film industry'],
#  ['directorial  project', 'grossing tamil 2016'],
#  ['atlee kumar', 'tamil film industry'],
#  ['directorial  project', 'grossing tamil 2016'],
#  ['increasingly film festivals', 'films'],
#  ['festivals', 'specific film maker'],
#  ['prestigious film festivals', 'world'],
#  ['venice film festival', 'oldest film world'],
#  ['first film festival', 'international sydney film festival'],
#  ['short film festival', 'yorkton film 1947'],
#  ['sundance film festival', 'south tribeca film southwest'],
#  ['arbor film festival', '1963'],
#  ['independent film festival', 'uk'],
#  ['few film festivals', 'specific issues/ subjects'],
#  ['festivals', 'mainstream  films'],
#  ['examples', 'related film festivals'],
#  ['', 'john thimothy'],
#  ['hot  docs', 'filmmaker paul jay'],
#  ['whistler film festival', '80  screenings'],
#  ['international film festival', 'competitive film mexico'],
#  ['it', 'important film chile'],
#  ['focus', 'american  cinema'],
#  ['many film festivals', 'exclusively  animation'],
#  ['notable  festivals', 'international film festival'],
#  ['they', 'prestigious film world'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['soft  emphasis', 'car culture'],
#  ['visual company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram'],
#  ['additionally parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['', 'mixed  reviews'],
#  ['models', 'renowned designer eric tscherne'],
#  ['franchise', 'short  films'],
#  ['it', 'universal  pictures'],
#  ['final  films', '2020'],
#  ['soft  emphasis', 'car culture'],
#  ['visual company weta digital', 'likeness'],
#  ['ultimately  film', 'april'],
#  ['cast', 'ghost hologram'],
#  ['additionally parkour athletes', 'drivers'],
#  ['following  list', 'website'],
#  ['', 'mixed  reviews'],
#  ['models', 'renowned designer eric tscherne'],
#  ['dual voting system', '1956'],
#  ['filmfare awards', 'first  1954'],
#  ['people choice award', 'short  khamakha'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['meena', 'rafiasha bhoslekishore'],
#  ['dual voting system', '1956'],
#  ['filmfare awards', 'first  1954'],
#  ['people choice award', 'short  khamakha'],
#  ['so  ceremony', 'next  year'],
#  ['two  reasons', 'change'],
#  ['theme', 'hundred  future'],
#  ['meena', 'rafiasha bhoslekishore'],
#  ['batman series', 'grossing north america'],
#  ['film', 'cave'],
#  ['played johnny duncan', 'robin'],
#  ['film', 'leslie'],
#  ['late  popularity', 'late  1970s'],
#  ['holden', '1981'],
#  ['nine  rewrites', 'separate  writers'],
#  ['final  salary', '$ 50 million'],
#  ['rewrites', 'warren skaaren'],
#  ['filming', 'warner bros'],
#  ['film', 'more  money'],
#  ['', 'arnold .'],
#  ['then  idea', 'them'],
#  ['he', 'warner bros'],
#  ['aronofsky', 'batman franchise'],
#  ['joss whedon', 'december'],
#  ['it', 'also  no'],
#  ['rises', 'batman trilogy'],
#  ['bane', 'selina kyle'],
#  ['charles roven', 'also  film'],
#  ['history', 'killer croc'],
#  ['film', 'early  2019'],
#  ['calotype process', 'paper negatives'],
#  ['transparent plastic roll film', '1889'],
#  ['it', 'flammable  nitrocellulose'],
#  ['photographic  plates', 'only  blue'],
#  ['however  all', 'these'],
#  ['commercially color film', 'lumière glass plate 1907'],
#  ['it', 'snapshot  use'],
#  ['film', '278  patents'],
#  ['photographic  lenses', 'film'],
#  ['this', 'when color film'],
#  ['filters', 'different film types'],
#  ['subject  matter', 'heavy  exposure'],
#  ['automatic  cameras', 'average  density'],
#  ['fourth naming standard', 'russian standards authority'],
#  ['common film speeds', 'iso'],
#  ['expensive  lenses', 'quartz'],
#  ['apochromatic  lenses', 'sometimes  spectrum'],
#  ['9.5  mm', ''],
#  ['first alfred thriller', 'silent london fog'],
#  ['film', 'future james bond films'],
#  ['action scenes', 'more thriller genre'],
#  ['such  films', 'silver streak'],
#  ['such  films', 'often  criminal'],
#  ['central  topics', 'killers  murders'],
#  ['genre', 'late  1960s'],
#  ['examples', 'pelican  brief'],
#  ['other  examples', 'tall  man'],
#  ['sometimes  protagonist', 'psychic  ability'],
#  ['examples', 'thirteenth  floor'],
#  ['loft', 'erotic erik van looy'],
#  ['', ''],
#  ['chris he', 'ann'],
#  ['production', 'july'],
#  ['loft', 'negative  reviews'],
#  ['brief saruman imprisons', 'brief  battle'],
#  ['bilbo', 'frodo  sword'],
#  ['fellowship', 'then uruk hai'],
#  ['slays watches', ''],
#  ['gandalf', 'defeated  palantír'],
#  ['gandalf  sauron', 'capital minas tirith'],
#  ['gollum  attacks', 'chasm'],
#  ['fellowship', 'ring'],
#  ['peter we', 'it'],
#  ['jackson', 'own film production company'],
#  ['jackson', 'favourite new zealand'],
#  ['2009  dispute', '8  september'],
#  ['numerous video games', 'film series'],
#  ['aladdin', 'musical walt disney pictures'],
#  ['aladdin', 'new  life'],
#  ['numan acar', 'hakim'],
#  ['musical  sequence', '1000  dancers'],
#  ['cgi scenes', 'better  notices'],
#  ['international  openings', 'china'],
#  ['you', 'original  film'],
#  ['film', 'july'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'may'],
#  ['film', 'june'],
#  ['james mangold', 'later  film'],
#  ['mark bomback', 'then  script'],
#  ['film', 'july'],
#  ['screenplay', 'kinberg'],
#  ['visual specialist tim miller', 'april'],
#  ['film', 'february'],
#  ['film', 'may'],
#  ['superheroes', 'risky  missions'],
#  ['additional  filming', 'august'],
#  ['film', 'june'],
#  ['records', 'three  films'],
#  ['morris', 'men'],
#  ['two  films', 'cerebral  tone'],
#  ['later  zombie', 'white  zombie'],
#  ['second studio album', 'second united states'],
#  ['third studio album', 'earlier  recordings'],
#  ['he', 'fifth studio album'],
#  ['live  shows', 'elaborate shock rock theatricality'],
#  ['he', 'oldest  cummings'],
#  ['younger  brother', 'lead band powerman'],
#  ['zombie', 'album rob'],
#  ['second studio album', 'sinister november'],
#  ['album', 'second  single'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  2', 'february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'lowest selling date'],
#  ['album', 'april'],
#  ['zombie', 'it'],
#  ['film', 'yet release date'],
#  ['he', 'white  zombie'],
#  ['later  zombie', 'white  zombie'],
#  ['second studio album', 'second united states'],
#  ['third studio album', 'earlier  recordings'],
#  ['he', 'fifth studio album'],
#  ['live  shows', 'elaborate shock rock theatricality'],
#  ['he', 'oldest  cummings'],
#  ['younger  brother', 'lead band powerman'],
#  ['zombie', 'album rob'],
#  ['second studio album', 'sinister november'],
#  ['album', 'second  single'],
#  ['film', 'theatrically  april'],
#  ['album', 'educated  march'],
#  ['film', 'grossing  date'],
#  ['ii', 'august'],
#  ['series', 'comic  book'],
#  ['hellbilly  2', 'february'],
#  ['tour', 'officially  december'],
#  ['we', 'plan'],
#  ['album', 'april'],
#  ['album', 'lowest selling date'],
#  ['album', 'april'],
#  ['zombie', 'it'],
#  ['film', 'yet release date'],
#  ['he', 'white  zombie'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'separate call times'],
#  ['take', 'everyone'],
#  ['camera camera', 'camera operator'],
#  ['video  film', 'film editor'],
#  ['visual  effects', 'digitally  artist'],
#  ['film', 'exhibition'],
#  ['parties', 'deal  contracts'],
#  ['step', 'actually  film'],
#  ['actors', 'separate call times'],
#  ['take', 'everyone'],
#  ['camera camera', 'camera operator'],
#  ['video  film', 'film editor'],
#  ['visual  effects', 'digitally  artist'],
#  ['film', 'exhibition'],
#  ['bbfc', 'uk age verification scheme'],
#  ['local  authorities', 'films'],
#  ['first 12a certificate', 'bourne identity'],
#  ['turnover', 'when job vacancies website'],
#  ['bbfc', 'also video games'],
#  ['bbfc guidelines', 'public  consultations'],
#  ['consultation', 'march'],
#  ['bbfc', 'following  certificates'],
#  ['they', 'licensed  cinemas'],
#  ['foreign language film', 'award'],
#  ['foreign language film it', 'foreign language film award'],
#  ['animated  films', 'also  category'],
#  ['film', 'nomination'],
#  ['one  film', 'country'],
#  ['arab  film', 'foreign language film award'],
#  ['such  films', 'underground  channels'],
#  ['pornographic  films', 'softcore  pornography'],
#  ['it', 'sexual  activity'],
#  ['two', 'earliest  pioneers'],
#  ['gyrating  pelvis', 'earliest  films'],
#  ['however  none', 'pornographic  films'],
#  ['entrepreneurs', 'demand'],
#  ['term glamour', 'modeling  photography'],
#  ['european sex films', 'european  continent'],
#  ['debbie', 'dallas'],
#  ['nothing', 'this'],
#  ['it', 'dedicated industry publications'],
#  ['pornographic film studios', 'also  houston'],
#  ['traditionally  audience', 'pornographic  films'],
#  ['most  actors', 'certain  genres'],
#  ['they', 'normally  jewellery'],
#  ['annie', 'support group member'],
#  ['first  you', 'bloody  head'],
#  ['sundance film festival', 'annual sundance institute'],
#  ['2019 sundance film festival', '24  february'],
#  ['it', 'sterling van wagenen'],
#  ['first frank capra award', 'jimmy stewart'],
#  ['actor resident robert who', 'actor resident robert redford'],
#  ['2013 sundance london festival', '2013 car maker jaguar'],
#  ['2018  events', 'same  venue'],
#  ['war', 'siddharth action thriller anand'],
#  ['vaani kapoor', 'lead  role'],
#  ['who', 'martial south korea'],
#  ['themes', 'sanchit balhara'],
#  ['india', 'today  it'],
#  ['it', 'highest bollywood films'],
#  ['soon film production companies', 'all  world'],
#  ['technical  improvements', 'length'],
#  ['movies', 'victorian art age'],
#  ['technical  problems', '1923'],
#  ['film', 'painted  slides'],
#  ['first  films', 'device'],
#  ['technique', '1901 film scrooge'],
#  ['more james attack', 'china mission station'],
#  ['films', '1900'],
#  ['films', 'proper  plots'],
#  ['he', 'silent  films'],
#  ['jacksonville', 'african american film industry'],
#  ['film company', 'different  approach'],
#  ['trend', 'italy'],
#  ['f. percy smith', 'early charles urban'],
#  ['danish film companies', '1912'],
#  ['swedish film industry', 'danish  industry'],
#  ['important  man', 'svenskabiografteatern cinema chain'],
#  ['khanzhonkov company', 'so film 1918'],
#  ['i', 'french éclair company'],
#  ['exhibition venues', 'higher  prices'],
#  ['biggest  success', 'years'],
#  ['wark griffith', 'nation'],
#  ['german film industry', 'seriously  war'],
#  ['this', 'floodlights'],
#  ['shaped  slits', 'vertical  apertures'],
#  ['new  idea', 'still  photography'],
#  ['untitled  film', 'edward raymond turner'],
#  ['subsequently technicolor technique', 'subsequently  1916'],
#  ['american propaganda films', 'desperate  journey'],
#  ['it', 'greatest  time'],
#  ['gimmicks', 'also  audiences'],
#  ['disney', 'notably peter beauty'],
#  ['limelight', 'interesting  respect'],
#  ['kurosawa', 'seven films blood'],
#  ['hidden  fortress', 'george lucas star wars'],
#  ['series', '1962'],
#  ['bonnie', 'new  hollywood'],
#  ['classical  cinema', 'new hollywood producers'],
#  ['jeet kune', 'style'],
#  ['indian  film', 'time'],
#  ['same camera system', 'spy kids'],
#  ['silent  film', 'recorded  sound'],
#  ['pianists', 'sheet music'],
#  ['silent  film', 'retroactively  something'],
#  ['town movie theatres', 'usually  pianist'],
#  ['', 'groundbreaking w. nation'],
#  ['silent  film', 'modern day audiences'],
#  ['vaudeville', 'silent film actors'],
#  ['silent  films', 'intended  speeds'],
#  ['frame', 'times  screen'],
#  ['silent  projectors', '3-bladed  shutters'],
#  ['represented  fire', 'mysterious  atmosphere'],
#  ['early  studios', 'york city area'],
#  ['others films', 'fort lee'],
#  ['amounts', 'gross exhibition gross'],
#  ['australian film doctor plonk', 'silent rolf de heer'],
#  ['stage plays', 'silent film styles'],
#  ['blancanieves', 'silent pablo berger'],
#  ['short  that', 'silent film comedies'],
#  ['sheep', 'positive  reviews'],
#  ['aardman animations', 'morph  time'],
#  ['film', 'year'],
#  ['early  forms', 'motion pictures'],
#  ['color television', 'more  .'],
#  ['colour  photography', 'inaccurate  hues'],
#  ['color photography', 'mid-20th  century'],
#  ['sometimes  color', 'cover'],
#  ['many school yearbooks', 'entirely  black'],
#  ['early  forms', 'motion pictures'],
#  ['color television', 'more  .'],
#  ['colour  photography', 'inaccurate  hues'],
#  ['color photography', 'mid-20th  century'],
#  ['sometimes  color', 'cover'],
#  ['many school yearbooks', 'entirely  black'],
#  ['it', 'first it film series'],
#  ['wyatt oleff', 'chosen stephen roles'],
#  ['it', 'grossing horror time'],
#  ['kajganich', 'also  that'],
#  ['now  they', 'scary  clown'],
#  ['it', 'all  core'],
#  ['i', 'different  approach'],
#  ['kids', 'really  bill'],
#  ['it', 'arri alexa xt'],
#  ['look', 'lenses'],
#  ['he', 'natural  look'],
#  ['it', 'like  quality'],
#  ['so  i', 'away  it'],
#  ['it', 'just  sync'],
#  ['overall  response', 'face'],
#  ['internationally  film', '10,560  screens'],
#  ['hollywood reporter', 'that'],
#  ['brennan', 'awards season'],
#  ['evil clown pennywise', 'scary bill nightmares'],
#  ['ideally  we', 'march'],
#  ['part  one', 'only  kids'],
#  ['cinema historians', 'category'],
#  ['sensibility', 'warner bros'],
#  ['classic  film', 'maltese  falcon'],
#  ['one', 'others'],
#  ['it', 'british century subsidiary'],
#  ['noir film genre', 'cold  war'],
#  ['black christopher debut', 'classic overt noir'],
#  ['', ''],
#  ['', 'implacable  investigator'],
#  ['film noir', 'many  manners'],
#  ['dead carl men', 'plaid'],
#  ['noir parodies', 'darker  tones'],
#  ['final  act', 'parodic  strain'],
#  ['still  others', 'mood'],
#  ['survey', 'identifying  characteristics'],
#  ['faces', 'partially  darkness'],
#  ['', 'conventional hollywood filmmaking'],
#  ['robert montgomery', 'only  mirrors'],
#  ['', 'different  ways'],
#  ['archetypal  characters', 'many film noirs'],
#  ['bars', 'frequently gambling action'],
#  ['soundtrack', 'vidyasagar'],
#  ['film', 'moderate box office'],
#  ['135 camera film', 'standard  perforations'],
#  ['135  film', 'several emulsion types'],
#  ['perforation size', 'standard  specification'],
#  ['this', '38.00  mm'],
#  ['12 exposure rolls', 'daily  press'],
#  ['24×36 mm exposures', '1914'],
#  ['335', '23 mm stereo format'],
#  ['single lens reflex', 'kine 1936'],
#  ['gods', 'dramatic łukasz palkowski'],
#  ['afi', 'private  funding'],
#  ['prior  leaders', ''],
#  ['film training program', 'afi conservatory'],
#  ['first  class', 'filmmakers terrence malick'],
#  ['producer richard gladstein', 'july'],
#  ['afi catalog', '1968'],
#  ['year afi awards', 'outstanding  films'],
#  ['awards', 'competitive  excellence'],
#  ['american film market', 'afi fest'],
#  ['additional  sponsors', 'american airlines'],
#  ['afi docs', 'documentary washington'],
#  ['festival', '27,000 documentary enthusiasts'],
#  ['theatre afi center', 'cultural silver spring'],
#  ['deckard defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['', ''],
#  ['', ''],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios'],
#  ['production', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba', 'human  abilities'],
#  ['finally  they', 'samoa chopper destruction'],
#  ['latter', 'clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['reald 3d conversion', 'film'],
#  ['deckard defeat who', 'afterwards  director'],
#  ['group', 'victory'],
#  ['', ''],
#  ['', ''],
#  ['character', 'future  film'],
#  ['most  filming', 'shepperton studios'],
#  ['production', 'officially  january'],
#  ['same  method', 'mclaren'],
#  ['idris elba', 'human  abilities'],
#  ['finally  they', 'samoa chopper destruction'],
#  ['latter', 'clearangle'],
#  ['second  trailer', 'april'],
#  ['final  trailer', 'june'],
#  ['reald 3d conversion', 'film'],
#  ['film', 'long  camera'],
#  ['films', '1900'],
#  ['many  directors', 'artistic  bond'],
#  ['motion picture montage', 'motion picture terminology'],
#  ['classic  examples', 'rocky'],
#  ['two  shots', 'same tone value'],
#  ['assistant  editors', 'temporary  sound'],
#  ['lower budget features', 'one  assistant'],
#  ['organizational aspects job', 'best  management'],
#  ['assistant editing', 'career path'],
#  ['avn awards', 'american trade magazine avn'],
#  ['they', 'porn'],
#  ['xrco awards', 'rated critics organization'],
#  ['penny arcade attractions', 'topless women'],
#  ['', 'pornographic casey hit'],
#  ['they', 'commonly  20s'],
#  ['a', 'boxcover'],
#  ['she', 'power'],
#  ['five  she', 'phone calls'],
#  ['she', 'phone calls'],
#  ['you', 'gangbangs'],
#  ['they', 'even phone call'],
#  ['so  it', 'anal girl toy'],
#  ['most  actresses', 'adult industry'],
#  ['they', 'anyone'],
#  ['most contract girls', '$  60,000'],
#  ['average  male', '$  40,000'],
#  ['claims', 'public health authorities'],
#  ['breakdown  voltage', 'dielectric  films'],
#  ['this', 'current  rating'],
#  ['film', 'less  material'],
#  ['rated film capacitors', 'film metal foil construction'],
#  ['however metal foil capacitors', 'self healing properties'],
#  ['special  type', 'mku film capacitors'],
#  ['characteristics', 'mixed film materials'],
#  ['they', 'metallized  versions'],
#  ['table', '50 capacitance pf'],
#  ['they', 'metallized  versions'],
#  ['they', 'metallized  types'],
#  ['they', 'metallized  types'],
#  ['dielectric absorption performance', 'only  ptfe'],
#  ['ptfe', 'often dupont trademark teflon'],
#  ['wound', ''],
#  ['specific series film capacitors', '2012'],
#  ['offered film capacitor', 'kapton dhgate'],
#  ['iec standards', 'european  standards'],
#  ['many  manufacturers', 'standard  abbreviations'],
#  ['required capacitance tolerance', 'particular  application'],
#  ['derating  factors', 'dc'],
#  ['allowable peak value', 'alternating  voltage'],
#  ['film capacitors', 'alternating  voltage'],
#  ['capacitors', 'effect'],
#  ['', 'equivalent  capacitor'],
#  ['dissipation factor', 'film capacitors'],
#  ['film capacitors', 'aging  processes'],
#  ['main  advantages', 'film capacitors'],
#  ['snubber capacitors', 'low self inductance'],
#  ['important  criteria', 'application'],
#  ['called snubber capacitors', 'special construction features'],
#  ['ac', ''],
#  ['surge discharge capacitors', 'current  surges'],
#  ['power capacitors', 'physical  dimensions'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'also information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['el apóstol', 'animated cutout animation'],
#  ['terrytoons', 'tom terrific'],
#  ['animation market', '2008'],
#  ['today  drawings', 'directly computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', '3d polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['most  animations', 'generated  imagery'],
#  ['animation', 'also information technology interfaces'],
#  ['little winsor nemo', 'detailed  drawings'],
#  ['el apóstol', 'animated cutout animation'],
#  ['terrytoons', 'tom terrific'],
#  ['animation market', '2008'],
#  ['today  drawings', 'directly computer system'],
#  ['3d  animation', 'digitally  animator'],
#  ['animator', '3d polygon mesh'],
#  ['traits', 'live  action'],
#  ['list', 'awardees'],
#  ['area', 'jubilee hills'],
#  ['mmts train station', 'hitec city'],
#  ['film roll', 'film cameras'],
#  ['where  film', 'advantages'],
#  ['digital  systems', 'different cost emphases'],
#  ['digital  cameras', 'more film equivalents'],
#  ['prices', 'intense  competition'],
#  ['film', 'torre giacomo vendruscolo'],
#  ['it', 'television series boris'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['neil', 'set  piece'],
#  ['schwarzenegger', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'misogynistic internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model', 'mortal  kombat'],
#  ['schwarzenegger', 'later  role'],
#  ['story', 'miller'],
#  ['', 'script'],
#  ['she', 'harder  anybody'],
#  ['neil', 'set  piece'],
#  ['schwarzenegger', 'october'],
#  ['certain  scenes', 'rated  violence'],
#  ['it', 'misogynistic internet comments'],
#  ['theatrical  trailers', 'august'],
#  ['game', 'september'],
#  ['t-800 model', 'mortal  kombat'],
#  ['suspense', 'important plot element'],
#  ['mystery films', 'mainly  crime'],
#  ['women', 'films'],
#  ['earliest mystery films', 'silent  era'],
#  ['film', 'more  1953'],
#  ['two  films', 'now  1909'],
#  ['story', 'again  1993'],
#  ...]

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
kg_df
# Out:
#                  source                           target          edge
# 0                connie                              own       decides
# 1          later  woman                         distance      heard in
# 2             christian                      then  elder  paralyzed by
# 3                temple                             fire        set on
# 4         outside  cult                              him    wails with
# ...                 ...                              ...           ...
# 4313       confidencial                 negatively  film     responded
# 4314        le parisien                 five star rating          gave
# 4315  museum collection               37,000 film titles      includes
# 4316        predecessor             historical film 1946           was
# 4317                     1920'sfilmstar alexander binder      garbo by
#
# [4318 rows x 3 columns]

# %% [markdown]
# * Next, we will use the networkx library to create a network from this dataframe. The nodes will represent the entities and the edges or connections between the nodes will represent the relations between the nodes.
#
#
# * It is going to be a directed graph. In other words, the relation between any connected node pair is not two-way, it is only from one node to another. For example, `John eats pasta`:

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %% [markdown]
# * Let’s plot the network:

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# * Well, this is not exactly what we were hoping for (still looks quite a sight though!).
#
# * It turns out that we have created a graph with all the relations that we had. It becomes really hard to visualize a graph with these many relations or predicates.
#
# * So, it’s advisable to use only a few important relations to visualize a graph. I will take one relation at a time. Let’s start with the relation “composed by”:

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# * That’s a much cleaner graph. Here the arrows point towards the composers. For instance, A.R. Rahman, who is a renowned music composer, has entities like “soundtrack score”, “film score”, and “music” connected to him in the graph above.
#
# * Let’s check out a few more relations.
#
# * Since writing is an important role in any movie, I would like to visualize the graph for the “written by” relation:

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# * Awesome! This `knowledge graph` is giving us some extraordinary information. Guys like Javed Akhtar, Krishna Chaitanya, and Jaideep Sahni are all famous lyricists and this graph beautifully captures this relationship.
#
# * Let’s see the knowledge graph of another important predicate, i.e., the `released in`:

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# * I can see quite a few interesting information in this graph. For example, look at this relationship – “several action horror movies released in the 1980s” and “pk released on 4844 screens”. These are facts and it shows us that we can mine such facts from just text. That’s quite amazing!

# %% [markdown]
# ---
# # Clustering and Classification using Knowledge Graph Embeddings
# ---
#
# * In this part we will explore how to use the `knowledge embeddings` generated by a graph of international football matches (since the 19th century) in `clustering and classification tasks.`
#
# * **Knowledge graph embeddings** are typically used for missing link prediction and knowledge discovery, but they can also be used for entity clustering, entity disambiguation, and other downstream tasks. The embeddings are a form of representation learning that allow linear algebra and machine learning to be applied to knowledge graphs, which otherwise would be difficult to do.
#
#
# * In this part we will cover:
#
# 1. Creating the knowledge graph (i.e. triples) from a tabular dataset of football matches
# 2. Training the `ComplEx embedding model` on those triples
# 3. Evaluating the quality of the embeddings on a validation set
# 4. Clustering the embeddings, comparing to the natural clusters formed by the geographical continents
# 5. Applying the embeddings as features in classification task, to predict match results
# 6. Evaluating the predictive model on a out-of-time test set, comparing to a simple baseline
#
# * We will show that knowledge embedding clusters manage to capture implicit geographical information from the graph and that they can be a useful feature source for a downstream machine learning classification task, significantly increasing accuracy from the baseline.
#
# ---

# %% [markdown]
# ## Requirements
#
# * We will use a Knowledge graph package called **AmpliGraph**.
#
# (http://docs.ampligraph.org/en/latest/install.html).

# %%
# %%capture
# !pip install ampligraph

import numpy as np
import pandas as pd
import ampligraph

ampligraph.__version__

# %% [markdown]
# ## Dataset
#
# We will use the [International football results from 1872 to 2019](https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017) available at Kaggle (public domain). It contains over 40 thousand international football matches. Each row contains the following information:
# 1. Match date
# 2. Home team name
# 3. Away team name
# 4. Home score (goals including extra time)
# 5. Away score (goals including extra time)
# 6. Tournament (whether it was a friendly match or part of a tournament)
# 7. City where match took place
# 8. Country where match took place
# 9. Whether match was on neutral grounds
#
# This dataset comes in a tabular format, therefore we will need to construct the knowledge graph ourselves.

# %%
import requests
url = 'https://ampligraph.s3-eu-west-1.amazonaws.com/datasets/football_graph.csv'
open('football_results.csv', 'wb').write(requests.get(url).content)
# Out:
# 3033782

# %%
df = pd.read_csv("football_results.csv").sort_values("date")

# %%
df.isna().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    2
# away_score    2
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %% [markdown]
# Dropping matches with unknown score:

# %%
df = df.dropna()

# %% [markdown]
# The training set will be from 1872 to 2014, while the test set will be from 2014 to present date. Note that a temporal test set makes any machine learning task harder compared to a random shuffle.

# %%
df["train"] = df.date < "2014-01-01"

# %%
df.train.value_counts()
# Out:
# True     35714
# False     5057
# Name: train, dtype: int64

# %% [markdown]
# ## Knowledge graph creation
# We are going to create a knowledge graph from scratch based on the match information. The idea is that each match is an entity that will be connected to its participating teams, geography, characteristics, and results.
#
# The objective is to generate a new representation of the dataset where each data point is an triple in the form:
#
#     <subject, predicate, object>
#
# First we need to create the entities (subjects and objects) that will form the graph. We make sure teams and geographical information result in different entities (e.g. the Brazilian team and the corresponding country will be different).

# %%
# Entities naming
df["match_id"] = df.index.values.astype(str)
df["match_id"] =  "Match" + df.match_id
df["city_id"] = "City" + df.city.str.title().str.replace(" ", "")
df["country_id"] = "Country" + df.country.str.title().str.replace(" ", "")
df["home_team_id"] = "Team" + df.home_team.str.title().str.replace(" ", "")
df["away_team_id"] = "Team" + df.away_team.str.title().str.replace(" ", "")
df["tournament_id"] = "Tournament" + df.tournament.str.title().str.replace(" ", "")
df["neutral"] = df.neutral.astype(str)

# %% [markdown]
# Then, we create the actual triples based on the relationship between the entities. We do it only for the triples in the training set (before 2014).

# %%
df
# Out:
#              date    home_team away_team  home_score  away_score  \
# 0      1872-11-30     Scotland   England         0.0         0.0
# 1      1873-03-08      England  Scotland         4.0         2.0
# 2      1874-03-07     Scotland   England         2.0         1.0
# 3      1875-03-06      England  Scotland         2.0         2.0
# 4      1876-03-04     Scotland   England         3.0         0.0
# ...           ...          ...       ...         ...         ...
# 40766  2019-07-10      Senegal     Benin         1.0         0.0
# 40767  2019-07-11  Ivory Coast   Algeria         1.0         1.0
# 40768  2019-07-11   Madagascar   Tunisia         0.0         3.0
# 40769  2019-07-14      Algeria   Nigeria         2.0         1.0
# 40770  2019-07-14      Senegal   Tunisia         1.0         0.0
#
#                    tournament     city   country neutral  train    match_id  \
# 0                    Friendly  Glasgow  Scotland   False   True      Match0
# 1                    Friendly   London   England   False   True      Match1
# 2                    Friendly  Glasgow  Scotland   False   True      Match2
# 3                    Friendly   London   England   False   True      Match3
# 4                    Friendly  Glasgow  Scotland   False   True      Match4
# ...                       ...      ...       ...     ...    ...         ...
# 40766  African Cup of Nations    Cairo     Egypt    True  False  Match40766
# 40767  African Cup of Nations     Suez     Egypt    True  False  Match40767
# 40768  African Cup of Nations    Cairo     Egypt    True  False  Match40768
# 40769  African Cup of Nations    Cairo     Egypt    True  False  Match40769
# 40770  African Cup of Nations    Cairo     Egypt    True  False  Match40770
#
#            city_id       country_id    home_team_id  away_team_id  \
# 0      CityGlasgow  CountryScotland    TeamScotland   TeamEngland
# 1       CityLondon   CountryEngland     TeamEngland  TeamScotland
# 2      CityGlasgow  CountryScotland    TeamScotland   TeamEngland
# 3       CityLondon   CountryEngland     TeamEngland  TeamScotland
# 4      CityGlasgow  CountryScotland    TeamScotland   TeamEngland
# ...            ...              ...             ...           ...
# 40766    CityCairo     CountryEgypt     TeamSenegal     TeamBenin
# 40767     CitySuez     CountryEgypt  TeamIvoryCoast   TeamAlgeria
# 40768    CityCairo     CountryEgypt  TeamMadagascar   TeamTunisia
# 40769    CityCairo     CountryEgypt     TeamAlgeria   TeamNigeria
# 40770    CityCairo     CountryEgypt     TeamSenegal   TeamTunisia
#
#                        tournament_id
# 0                 TournamentFriendly
# 1                 TournamentFriendly
# 2                 TournamentFriendly
# 3                 TournamentFriendly
# 4                 TournamentFriendly
# ...                              ...
# 40766  TournamentAfricanCupOfNations
# 40767  TournamentAfricanCupOfNations
# 40768  TournamentAfricanCupOfNations
# 40769  TournamentAfricanCupOfNations
# 40770  TournamentAfricanCupOfNations
#
# [40771 rows x 16 columns]

# %%
triples = []
for _, row in df[df["train"]].iterrows():
    # Home and away information
    home_team = (row["home_team_id"], "isHomeTeamIn", row["match_id"])
    away_team = (row["away_team_id"], "isAwayTeamIn", row["match_id"])
    
    # Match results
    if row["home_score"] > row["away_score"]:
        score_home = (row["home_team_id"], "winnerOf", row["match_id"])
        score_away = (row["away_team_id"], "loserOf", row["match_id"])
    elif row["home_score"] < row["away_score"]:
        score_away = (row["away_team_id"], "winnerOf", row["match_id"])
        score_home = (row["home_team_id"], "loserOf", row["match_id"])
    else:
        score_home = (row["home_team_id"], "draws", row["match_id"])
        score_away = (row["away_team_id"], "draws", row["match_id"])
    home_score = (row["match_id"], "homeScores", np.clip(int(row["home_score"]), 0, 5))
    away_score = (row["match_id"], "awayScores", np.clip(int(row["away_score"]), 0, 5))
    
    # Match characteristics
    tournament = (row["match_id"], "inTournament", row["tournament_id"])
    city = (row["match_id"], "inCity", row["city_id"])
    country = (row["match_id"], "inCountry", row["country_id"])
    neutral = (row["match_id"], "isNeutral", row["neutral"])
    year = (row["match_id"], "atYear", row["date"][:4])
    
    triples.extend((home_team, away_team, score_home, score_away, 
                    tournament, city, country, neutral, year, home_score, away_score))

# %%
type(triples)
# Out:
# list

# %%
triples
# Out:
# [('TeamScotland', 'isHomeTeamIn', 'Match0'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match0'),
#  ('TeamScotland', 'draws', 'Match0'),
#  ('TeamEngland', 'draws', 'Match0'),
#  ('Match0', 'inTournament', 'TournamentFriendly'),
#  ('Match0', 'inCity', 'CityGlasgow'),
#  ('Match0', 'inCountry', 'CountryScotland'),
#  ('Match0', 'isNeutral', 'False'),
#  ('Match0', 'atYear', '1872'),
#  ('Match0', 'homeScores', 0),
#  ('Match0', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match1'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match1'),
#  ('TeamEngland', 'winnerOf', 'Match1'),
#  ('TeamScotland', 'loserOf', 'Match1'),
#  ('Match1', 'inTournament', 'TournamentFriendly'),
#  ('Match1', 'inCity', 'CityLondon'),
#  ('Match1', 'inCountry', 'CountryEngland'),
#  ('Match1', 'isNeutral', 'False'),
#  ('Match1', 'atYear', '1873'),
#  ('Match1', 'homeScores', 4),
#  ('Match1', 'awayScores', 2),
#  ('TeamScotland', 'isHomeTeamIn', 'Match2'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match2'),
#  ('TeamScotland', 'winnerOf', 'Match2'),
#  ('TeamEngland', 'loserOf', 'Match2'),
#  ('Match2', 'inTournament', 'TournamentFriendly'),
#  ('Match2', 'inCity', 'CityGlasgow'),
#  ('Match2', 'inCountry', 'CountryScotland'),
#  ('Match2', 'isNeutral', 'False'),
#  ('Match2', 'atYear', '1874'),
#  ('Match2', 'homeScores', 2),
#  ('Match2', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match3'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match3'),
#  ('TeamEngland', 'draws', 'Match3'),
#  ('TeamScotland', 'draws', 'Match3'),
#  ('Match3', 'inTournament', 'TournamentFriendly'),
#  ('Match3', 'inCity', 'CityLondon'),
#  ('Match3', 'inCountry', 'CountryEngland'),
#  ('Match3', 'isNeutral', 'False'),
#  ('Match3', 'atYear', '1875'),
#  ('Match3', 'homeScores', 2),
#  ('Match3', 'awayScores', 2),
#  ('TeamScotland', 'isHomeTeamIn', 'Match4'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match4'),
#  ('TeamScotland', 'winnerOf', 'Match4'),
#  ('TeamEngland', 'loserOf', 'Match4'),
#  ('Match4', 'inTournament', 'TournamentFriendly'),
#  ('Match4', 'inCity', 'CityGlasgow'),
#  ('Match4', 'inCountry', 'CountryScotland'),
#  ('Match4', 'isNeutral', 'False'),
#  ('Match4', 'atYear', '1876'),
#  ('Match4', 'homeScores', 3),
#  ('Match4', 'awayScores', 0),
#  ('TeamScotland', 'isHomeTeamIn', 'Match5'),
#  ('TeamWales', 'isAwayTeamIn', 'Match5'),
#  ('TeamScotland', 'winnerOf', 'Match5'),
#  ('TeamWales', 'loserOf', 'Match5'),
#  ('Match5', 'inTournament', 'TournamentFriendly'),
#  ('Match5', 'inCity', 'CityGlasgow'),
#  ('Match5', 'inCountry', 'CountryScotland'),
#  ('Match5', 'isNeutral', 'False'),
#  ('Match5', 'atYear', '1876'),
#  ('Match5', 'homeScores', 4),
#  ('Match5', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match6'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match6'),
#  ('TeamEngland', 'loserOf', 'Match6'),
#  ('TeamScotland', 'winnerOf', 'Match6'),
#  ('Match6', 'inTournament', 'TournamentFriendly'),
#  ('Match6', 'inCity', 'CityLondon'),
#  ('Match6', 'inCountry', 'CountryEngland'),
#  ('Match6', 'isNeutral', 'False'),
#  ('Match6', 'atYear', '1877'),
#  ('Match6', 'homeScores', 1),
#  ('Match6', 'awayScores', 3),
#  ('TeamWales', 'isHomeTeamIn', 'Match7'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match7'),
#  ('TeamWales', 'loserOf', 'Match7'),
#  ('TeamScotland', 'winnerOf', 'Match7'),
#  ('Match7', 'inTournament', 'TournamentFriendly'),
#  ('Match7', 'inCity', 'CityWrexham'),
#  ('Match7', 'inCountry', 'CountryWales'),
#  ('Match7', 'isNeutral', 'False'),
#  ('Match7', 'atYear', '1877'),
#  ('Match7', 'homeScores', 0),
#  ('Match7', 'awayScores', 2),
#  ('TeamScotland', 'isHomeTeamIn', 'Match8'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match8'),
#  ('TeamScotland', 'winnerOf', 'Match8'),
#  ('TeamEngland', 'loserOf', 'Match8'),
#  ('Match8', 'inTournament', 'TournamentFriendly'),
#  ('Match8', 'inCity', 'CityGlasgow'),
#  ('Match8', 'inCountry', 'CountryScotland'),
#  ('Match8', 'isNeutral', 'False'),
#  ('Match8', 'atYear', '1878'),
#  ('Match8', 'homeScores', 5),
#  ('Match8', 'awayScores', 2),
#  ('TeamScotland', 'isHomeTeamIn', 'Match9'),
#  ('TeamWales', 'isAwayTeamIn', 'Match9'),
#  ('TeamScotland', 'winnerOf', 'Match9'),
#  ('TeamWales', 'loserOf', 'Match9'),
#  ('Match9', 'inTournament', 'TournamentFriendly'),
#  ('Match9', 'inCity', 'CityGlasgow'),
#  ('Match9', 'inCountry', 'CountryScotland'),
#  ('Match9', 'isNeutral', 'False'),
#  ('Match9', 'atYear', '1878'),
#  ('Match9', 'homeScores', 5),
#  ('Match9', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match10'),
#  ('TeamWales', 'isAwayTeamIn', 'Match10'),
#  ('TeamEngland', 'winnerOf', 'Match10'),
#  ('TeamWales', 'loserOf', 'Match10'),
#  ('Match10', 'inTournament', 'TournamentFriendly'),
#  ('Match10', 'inCity', 'CityLondon'),
#  ('Match10', 'inCountry', 'CountryEngland'),
#  ('Match10', 'isNeutral', 'False'),
#  ('Match10', 'atYear', '1879'),
#  ('Match10', 'homeScores', 2),
#  ('Match10', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match11'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match11'),
#  ('TeamEngland', 'winnerOf', 'Match11'),
#  ('TeamScotland', 'loserOf', 'Match11'),
#  ('Match11', 'inTournament', 'TournamentFriendly'),
#  ('Match11', 'inCity', 'CityLondon'),
#  ('Match11', 'inCountry', 'CountryEngland'),
#  ('Match11', 'isNeutral', 'False'),
#  ('Match11', 'atYear', '1879'),
#  ('Match11', 'homeScores', 5),
#  ('Match11', 'awayScores', 4),
#  ('TeamWales', 'isHomeTeamIn', 'Match12'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match12'),
#  ('TeamWales', 'loserOf', 'Match12'),
#  ('TeamScotland', 'winnerOf', 'Match12'),
#  ('Match12', 'inTournament', 'TournamentFriendly'),
#  ('Match12', 'inCity', 'CityWrexham'),
#  ('Match12', 'inCountry', 'CountryWales'),
#  ('Match12', 'isNeutral', 'False'),
#  ('Match12', 'atYear', '1879'),
#  ('Match12', 'homeScores', 0),
#  ('Match12', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match13'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match13'),
#  ('TeamScotland', 'winnerOf', 'Match13'),
#  ('TeamEngland', 'loserOf', 'Match13'),
#  ('Match13', 'inTournament', 'TournamentFriendly'),
#  ('Match13', 'inCity', 'CityGlasgow'),
#  ('Match13', 'inCountry', 'CountryScotland'),
#  ('Match13', 'isNeutral', 'False'),
#  ('Match13', 'atYear', '1880'),
#  ('Match13', 'homeScores', 5),
#  ('Match13', 'awayScores', 4),
#  ('TeamWales', 'isHomeTeamIn', 'Match14'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match14'),
#  ('TeamWales', 'loserOf', 'Match14'),
#  ('TeamEngland', 'winnerOf', 'Match14'),
#  ('Match14', 'inTournament', 'TournamentFriendly'),
#  ('Match14', 'inCity', 'CityWrexham'),
#  ('Match14', 'inCountry', 'CountryWales'),
#  ('Match14', 'isNeutral', 'False'),
#  ('Match14', 'atYear', '1880'),
#  ('Match14', 'homeScores', 2),
#  ('Match14', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match15'),
#  ('TeamWales', 'isAwayTeamIn', 'Match15'),
#  ('TeamScotland', 'winnerOf', 'Match15'),
#  ('TeamWales', 'loserOf', 'Match15'),
#  ('Match15', 'inTournament', 'TournamentFriendly'),
#  ('Match15', 'inCity', 'CityGlasgow'),
#  ('Match15', 'inCountry', 'CountryScotland'),
#  ('Match15', 'isNeutral', 'False'),
#  ('Match15', 'atYear', '1880'),
#  ('Match15', 'homeScores', 5),
#  ('Match15', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match16'),
#  ('TeamWales', 'isAwayTeamIn', 'Match16'),
#  ('TeamEngland', 'loserOf', 'Match16'),
#  ('TeamWales', 'winnerOf', 'Match16'),
#  ('Match16', 'inTournament', 'TournamentFriendly'),
#  ('Match16', 'inCity', 'CityBlackburn'),
#  ('Match16', 'inCountry', 'CountryEngland'),
#  ('Match16', 'isNeutral', 'False'),
#  ('Match16', 'atYear', '1881'),
#  ('Match16', 'homeScores', 0),
#  ('Match16', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match17'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match17'),
#  ('TeamEngland', 'loserOf', 'Match17'),
#  ('TeamScotland', 'winnerOf', 'Match17'),
#  ('Match17', 'inTournament', 'TournamentFriendly'),
#  ('Match17', 'inCity', 'CityLondon'),
#  ('Match17', 'inCountry', 'CountryEngland'),
#  ('Match17', 'isNeutral', 'False'),
#  ('Match17', 'atYear', '1881'),
#  ('Match17', 'homeScores', 1),
#  ('Match17', 'awayScores', 5),
#  ('TeamWales', 'isHomeTeamIn', 'Match18'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match18'),
#  ('TeamWales', 'loserOf', 'Match18'),
#  ('TeamScotland', 'winnerOf', 'Match18'),
#  ('Match18', 'inTournament', 'TournamentFriendly'),
#  ('Match18', 'inCity', 'CityWrexham'),
#  ('Match18', 'inCountry', 'CountryWales'),
#  ('Match18', 'isNeutral', 'False'),
#  ('Match18', 'atYear', '1881'),
#  ('Match18', 'homeScores', 1),
#  ('Match18', 'awayScores', 5),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match19'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match19'),
#  ('TeamNorthernIreland', 'loserOf', 'Match19'),
#  ('TeamEngland', 'winnerOf', 'Match19'),
#  ('Match19', 'inTournament', 'TournamentFriendly'),
#  ('Match19', 'inCity', 'CityBelfast'),
#  ('Match19', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match19', 'isNeutral', 'False'),
#  ('Match19', 'atYear', '1882'),
#  ('Match19', 'homeScores', 0),
#  ('Match19', 'awayScores', 5),
#  ('TeamWales', 'isHomeTeamIn', 'Match20'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match20'),
#  ('TeamWales', 'winnerOf', 'Match20'),
#  ('TeamNorthernIreland', 'loserOf', 'Match20'),
#  ('Match20', 'inTournament', 'TournamentFriendly'),
#  ('Match20', 'inCity', 'CityWrexham'),
#  ('Match20', 'inCountry', 'CountryWales'),
#  ('Match20', 'isNeutral', 'False'),
#  ('Match20', 'atYear', '1882'),
#  ('Match20', 'homeScores', 5),
#  ('Match20', 'awayScores', 1),
#  ('TeamScotland', 'isHomeTeamIn', 'Match21'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match21'),
#  ('TeamScotland', 'winnerOf', 'Match21'),
#  ('TeamEngland', 'loserOf', 'Match21'),
#  ('Match21', 'inTournament', 'TournamentFriendly'),
#  ('Match21', 'inCity', 'CityGlasgow'),
#  ('Match21', 'inCountry', 'CountryScotland'),
#  ('Match21', 'isNeutral', 'False'),
#  ('Match21', 'atYear', '1882'),
#  ('Match21', 'homeScores', 5),
#  ('Match21', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match22'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match22'),
#  ('TeamWales', 'winnerOf', 'Match22'),
#  ('TeamEngland', 'loserOf', 'Match22'),
#  ('Match22', 'inTournament', 'TournamentFriendly'),
#  ('Match22', 'inCity', 'CityWrexham'),
#  ('Match22', 'inCountry', 'CountryWales'),
#  ('Match22', 'isNeutral', 'False'),
#  ('Match22', 'atYear', '1882'),
#  ('Match22', 'homeScores', 5),
#  ('Match22', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match23'),
#  ('TeamWales', 'isAwayTeamIn', 'Match23'),
#  ('TeamScotland', 'winnerOf', 'Match23'),
#  ('TeamWales', 'loserOf', 'Match23'),
#  ('Match23', 'inTournament', 'TournamentFriendly'),
#  ('Match23', 'inCity', 'CityGlasgow'),
#  ('Match23', 'inCountry', 'CountryScotland'),
#  ('Match23', 'isNeutral', 'False'),
#  ('Match23', 'atYear', '1882'),
#  ('Match23', 'homeScores', 5),
#  ('Match23', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match24'),
#  ('TeamWales', 'isAwayTeamIn', 'Match24'),
#  ('TeamEngland', 'winnerOf', 'Match24'),
#  ('TeamWales', 'loserOf', 'Match24'),
#  ('Match24', 'inTournament', 'TournamentFriendly'),
#  ('Match24', 'inCity', 'CityLondon'),
#  ('Match24', 'inCountry', 'CountryEngland'),
#  ('Match24', 'isNeutral', 'False'),
#  ('Match24', 'atYear', '1883'),
#  ('Match24', 'homeScores', 5),
#  ('Match24', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match25'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match25'),
#  ('TeamEngland', 'winnerOf', 'Match25'),
#  ('TeamNorthernIreland', 'loserOf', 'Match25'),
#  ('Match25', 'inTournament', 'TournamentFriendly'),
#  ('Match25', 'inCity', 'CityLiverpool'),
#  ('Match25', 'inCountry', 'CountryEngland'),
#  ('Match25', 'isNeutral', 'False'),
#  ('Match25', 'atYear', '1883'),
#  ('Match25', 'homeScores', 5),
#  ('Match25', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match26'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match26'),
#  ('TeamEngland', 'loserOf', 'Match26'),
#  ('TeamScotland', 'winnerOf', 'Match26'),
#  ('Match26', 'inTournament', 'TournamentFriendly'),
#  ('Match26', 'inCity', 'CitySheffield'),
#  ('Match26', 'inCountry', 'CountryEngland'),
#  ('Match26', 'isNeutral', 'False'),
#  ('Match26', 'atYear', '1883'),
#  ('Match26', 'homeScores', 2),
#  ('Match26', 'awayScores', 3),
#  ('TeamWales', 'isHomeTeamIn', 'Match27'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match27'),
#  ('TeamWales', 'loserOf', 'Match27'),
#  ('TeamScotland', 'winnerOf', 'Match27'),
#  ('Match27', 'inTournament', 'TournamentFriendly'),
#  ('Match27', 'inCity', 'CityWrexham'),
#  ('Match27', 'inCountry', 'CountryWales'),
#  ('Match27', 'isNeutral', 'False'),
#  ('Match27', 'atYear', '1883'),
#  ('Match27', 'homeScores', 0),
#  ('Match27', 'awayScores', 3),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match28'),
#  ('TeamWales', 'isAwayTeamIn', 'Match28'),
#  ('TeamNorthernIreland', 'draws', 'Match28'),
#  ('TeamWales', 'draws', 'Match28'),
#  ('Match28', 'inTournament', 'TournamentFriendly'),
#  ('Match28', 'inCity', 'CityBelfast'),
#  ('Match28', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match28', 'isNeutral', 'False'),
#  ('Match28', 'atYear', '1883'),
#  ('Match28', 'homeScores', 1),
#  ('Match28', 'awayScores', 1),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match29'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match29'),
#  ('TeamNorthernIreland', 'loserOf', 'Match29'),
#  ('TeamScotland', 'winnerOf', 'Match29'),
#  ('Match29', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match29', 'inCity', 'CityBelfast'),
#  ('Match29', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match29', 'isNeutral', 'False'),
#  ('Match29', 'atYear', '1884'),
#  ('Match29', 'homeScores', 0),
#  ('Match29', 'awayScores', 5),
#  ('TeamWales', 'isHomeTeamIn', 'Match30'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match30'),
#  ('TeamWales', 'winnerOf', 'Match30'),
#  ('TeamNorthernIreland', 'loserOf', 'Match30'),
#  ('Match30', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match30', 'inCity', 'CityWrexham'),
#  ('Match30', 'inCountry', 'CountryWales'),
#  ('Match30', 'isNeutral', 'False'),
#  ('Match30', 'atYear', '1884'),
#  ('Match30', 'homeScores', 5),
#  ('Match30', 'awayScores', 0),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match31'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match31'),
#  ('TeamNorthernIreland', 'loserOf', 'Match31'),
#  ('TeamEngland', 'winnerOf', 'Match31'),
#  ('Match31', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match31', 'inCity', 'CityBelfast'),
#  ('Match31', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match31', 'isNeutral', 'False'),
#  ('Match31', 'atYear', '1884'),
#  ('Match31', 'homeScores', 1),
#  ('Match31', 'awayScores', 5),
#  ('TeamScotland', 'isHomeTeamIn', 'Match32'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match32'),
#  ('TeamScotland', 'winnerOf', 'Match32'),
#  ('TeamEngland', 'loserOf', 'Match32'),
#  ('Match32', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match32', 'inCity', 'CityGlasgow'),
#  ('Match32', 'inCountry', 'CountryScotland'),
#  ('Match32', 'isNeutral', 'False'),
#  ('Match32', 'atYear', '1884'),
#  ('Match32', 'homeScores', 1),
#  ('Match32', 'awayScores', 0),
#  ('TeamWales', 'isHomeTeamIn', 'Match33'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match33'),
#  ('TeamWales', 'loserOf', 'Match33'),
#  ('TeamEngland', 'winnerOf', 'Match33'),
#  ('Match33', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match33', 'inCity', 'CityWrexham'),
#  ('Match33', 'inCountry', 'CountryWales'),
#  ('Match33', 'isNeutral', 'False'),
#  ('Match33', 'atYear', '1884'),
#  ('Match33', 'homeScores', 0),
#  ('Match33', 'awayScores', 4),
#  ('TeamScotland', 'isHomeTeamIn', 'Match34'),
#  ('TeamWales', 'isAwayTeamIn', 'Match34'),
#  ('TeamScotland', 'winnerOf', 'Match34'),
#  ('TeamWales', 'loserOf', 'Match34'),
#  ('Match34', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match34', 'inCity', 'CityGlasgow'),
#  ('Match34', 'inCountry', 'CountryScotland'),
#  ('Match34', 'isNeutral', 'False'),
#  ('Match34', 'atYear', '1884'),
#  ('Match34', 'homeScores', 4),
#  ('Match34', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match35'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match35'),
#  ('TeamEngland', 'winnerOf', 'Match35'),
#  ('TeamNorthernIreland', 'loserOf', 'Match35'),
#  ('Match35', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match35', 'inCity', 'CityManchester'),
#  ('Match35', 'inCountry', 'CountryEngland'),
#  ('Match35', 'isNeutral', 'False'),
#  ('Match35', 'atYear', '1885'),
#  ('Match35', 'homeScores', 4),
#  ('Match35', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match36'),
#  ('TeamWales', 'isAwayTeamIn', 'Match36'),
#  ('TeamEngland', 'draws', 'Match36'),
#  ('TeamWales', 'draws', 'Match36'),
#  ('Match36', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match36', 'inCity', 'CityBlackburn'),
#  ('Match36', 'inCountry', 'CountryEngland'),
#  ('Match36', 'isNeutral', 'False'),
#  ('Match36', 'atYear', '1885'),
#  ('Match36', 'homeScores', 1),
#  ('Match36', 'awayScores', 1),
#  ('TeamScotland', 'isHomeTeamIn', 'Match37'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match37'),
#  ('TeamScotland', 'winnerOf', 'Match37'),
#  ('TeamNorthernIreland', 'loserOf', 'Match37'),
#  ('Match37', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match37', 'inCity', 'CityGlasgow'),
#  ('Match37', 'inCountry', 'CountryScotland'),
#  ('Match37', 'isNeutral', 'False'),
#  ('Match37', 'atYear', '1885'),
#  ('Match37', 'homeScores', 5),
#  ('Match37', 'awayScores', 2),
#  ('TeamEngland', 'isHomeTeamIn', 'Match38'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match38'),
#  ('TeamEngland', 'draws', 'Match38'),
#  ('TeamScotland', 'draws', 'Match38'),
#  ('Match38', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match38', 'inCity', 'CityLondon'),
#  ('Match38', 'inCountry', 'CountryEngland'),
#  ('Match38', 'isNeutral', 'False'),
#  ('Match38', 'atYear', '1885'),
#  ('Match38', 'homeScores', 1),
#  ('Match38', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match39'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match39'),
#  ('TeamWales', 'loserOf', 'Match39'),
#  ('TeamScotland', 'winnerOf', 'Match39'),
#  ('Match39', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match39', 'inCity', 'CityWrexham'),
#  ('Match39', 'inCountry', 'CountryWales'),
#  ('Match39', 'isNeutral', 'False'),
#  ('Match39', 'atYear', '1885'),
#  ('Match39', 'homeScores', 1),
#  ('Match39', 'awayScores', 5),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match40'),
#  ('TeamWales', 'isAwayTeamIn', 'Match40'),
#  ('TeamNorthernIreland', 'loserOf', 'Match40'),
#  ('TeamWales', 'winnerOf', 'Match40'),
#  ('Match40', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match40', 'inCity', 'CityBelfast'),
#  ('Match40', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match40', 'isNeutral', 'False'),
#  ('Match40', 'atYear', '1885'),
#  ('Match40', 'homeScores', 2),
#  ('Match40', 'awayScores', 5),
#  ('TeamUnitedStates', 'isHomeTeamIn', 'Match41'),
#  ('TeamCanada', 'isAwayTeamIn', 'Match41'),
#  ('TeamUnitedStates', 'loserOf', 'Match41'),
#  ('TeamCanada', 'winnerOf', 'Match41'),
#  ('Match41', 'inTournament', 'TournamentFriendly'),
#  ('Match41', 'inCity', 'CityNewark'),
#  ('Match41', 'inCountry', 'CountryUnitedStates'),
#  ('Match41', 'isNeutral', 'False'),
#  ('Match41', 'atYear', '1885'),
#  ('Match41', 'homeScores', 0),
#  ('Match41', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match42'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match42'),
#  ('TeamWales', 'winnerOf', 'Match42'),
#  ('TeamNorthernIreland', 'loserOf', 'Match42'),
#  ('Match42', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match42', 'inCity', 'CityWrexham'),
#  ('Match42', 'inCountry', 'CountryWales'),
#  ('Match42', 'isNeutral', 'False'),
#  ('Match42', 'atYear', '1886'),
#  ('Match42', 'homeScores', 5),
#  ('Match42', 'awayScores', 0),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match43'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match43'),
#  ('TeamNorthernIreland', 'loserOf', 'Match43'),
#  ('TeamEngland', 'winnerOf', 'Match43'),
#  ('Match43', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match43', 'inCity', 'CityBelfast'),
#  ('Match43', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match43', 'isNeutral', 'False'),
#  ('Match43', 'atYear', '1886'),
#  ('Match43', 'homeScores', 1),
#  ('Match43', 'awayScores', 5),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match44'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match44'),
#  ('TeamNorthernIreland', 'loserOf', 'Match44'),
#  ('TeamScotland', 'winnerOf', 'Match44'),
#  ('Match44', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match44', 'inCity', 'CityBelfast'),
#  ('Match44', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match44', 'isNeutral', 'False'),
#  ('Match44', 'atYear', '1886'),
#  ('Match44', 'homeScores', 2),
#  ('Match44', 'awayScores', 5),
#  ('TeamScotland', 'isHomeTeamIn', 'Match45'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match45'),
#  ('TeamScotland', 'draws', 'Match45'),
#  ('TeamEngland', 'draws', 'Match45'),
#  ('Match45', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match45', 'inCity', 'CityGlasgow'),
#  ('Match45', 'inCountry', 'CountryScotland'),
#  ('Match45', 'isNeutral', 'False'),
#  ('Match45', 'atYear', '1886'),
#  ('Match45', 'homeScores', 1),
#  ('Match45', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match46'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match46'),
#  ('TeamWales', 'loserOf', 'Match46'),
#  ('TeamEngland', 'winnerOf', 'Match46'),
#  ('Match46', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match46', 'inCity', 'CityWrexham'),
#  ('Match46', 'inCountry', 'CountryWales'),
#  ('Match46', 'isNeutral', 'False'),
#  ('Match46', 'atYear', '1886'),
#  ('Match46', 'homeScores', 1),
#  ('Match46', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match47'),
#  ('TeamWales', 'isAwayTeamIn', 'Match47'),
#  ('TeamScotland', 'winnerOf', 'Match47'),
#  ('TeamWales', 'loserOf', 'Match47'),
#  ('Match47', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match47', 'inCity', 'CityGlasgow'),
#  ('Match47', 'inCountry', 'CountryScotland'),
#  ('Match47', 'isNeutral', 'False'),
#  ('Match47', 'atYear', '1886'),
#  ('Match47', 'homeScores', 4),
#  ('Match47', 'awayScores', 1),
#  ('TeamUnitedStates', 'isHomeTeamIn', 'Match48'),
#  ('TeamCanada', 'isAwayTeamIn', 'Match48'),
#  ('TeamUnitedStates', 'winnerOf', 'Match48'),
#  ('TeamCanada', 'loserOf', 'Match48'),
#  ('Match48', 'inTournament', 'TournamentFriendly'),
#  ('Match48', 'inCity', 'CityNewark'),
#  ('Match48', 'inCountry', 'CountryUnitedStates'),
#  ('Match48', 'isNeutral', 'False'),
#  ('Match48', 'atYear', '1886'),
#  ('Match48', 'homeScores', 3),
#  ('Match48', 'awayScores', 2),
#  ('TeamEngland', 'isHomeTeamIn', 'Match49'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match49'),
#  ('TeamEngland', 'winnerOf', 'Match49'),
#  ('TeamNorthernIreland', 'loserOf', 'Match49'),
#  ('Match49', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match49', 'inCity', 'CitySheffield'),
#  ('Match49', 'inCountry', 'CountryEngland'),
#  ('Match49', 'isNeutral', 'False'),
#  ('Match49', 'atYear', '1887'),
#  ('Match49', 'homeScores', 5),
#  ('Match49', 'awayScores', 0),
#  ('TeamScotland', 'isHomeTeamIn', 'Match50'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match50'),
#  ('TeamScotland', 'winnerOf', 'Match50'),
#  ('TeamNorthernIreland', 'loserOf', 'Match50'),
#  ('Match50', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match50', 'inCity', 'CityGlasgow'),
#  ('Match50', 'inCountry', 'CountryScotland'),
#  ('Match50', 'isNeutral', 'False'),
#  ('Match50', 'atYear', '1887'),
#  ('Match50', 'homeScores', 4),
#  ('Match50', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match51'),
#  ('TeamWales', 'isAwayTeamIn', 'Match51'),
#  ('TeamEngland', 'winnerOf', 'Match51'),
#  ('TeamWales', 'loserOf', 'Match51'),
#  ('Match51', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match51', 'inCity', 'CityLondon'),
#  ('Match51', 'inCountry', 'CountryEngland'),
#  ('Match51', 'isNeutral', 'False'),
#  ('Match51', 'atYear', '1887'),
#  ('Match51', 'homeScores', 4),
#  ('Match51', 'awayScores', 0),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match52'),
#  ('TeamWales', 'isAwayTeamIn', 'Match52'),
#  ('TeamNorthernIreland', 'winnerOf', 'Match52'),
#  ('TeamWales', 'loserOf', 'Match52'),
#  ('Match52', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match52', 'inCity', 'CityBelfast'),
#  ('Match52', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match52', 'isNeutral', 'False'),
#  ('Match52', 'atYear', '1887'),
#  ('Match52', 'homeScores', 4),
#  ('Match52', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match53'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match53'),
#  ('TeamEngland', 'loserOf', 'Match53'),
#  ('TeamScotland', 'winnerOf', 'Match53'),
#  ('Match53', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match53', 'inCity', 'CityBlackburn'),
#  ('Match53', 'inCountry', 'CountryEngland'),
#  ('Match53', 'isNeutral', 'False'),
#  ('Match53', 'atYear', '1887'),
#  ('Match53', 'homeScores', 2),
#  ('Match53', 'awayScores', 3),
#  ('TeamWales', 'isHomeTeamIn', 'Match54'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match54'),
#  ('TeamWales', 'loserOf', 'Match54'),
#  ('TeamScotland', 'winnerOf', 'Match54'),
#  ('Match54', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match54', 'inCity', 'CityWrexham'),
#  ('Match54', 'inCountry', 'CountryWales'),
#  ('Match54', 'isNeutral', 'False'),
#  ('Match54', 'atYear', '1887'),
#  ('Match54', 'homeScores', 0),
#  ('Match54', 'awayScores', 2),
#  ('TeamEngland', 'isHomeTeamIn', 'Match55'),
#  ('TeamWales', 'isAwayTeamIn', 'Match55'),
#  ('TeamEngland', 'winnerOf', 'Match55'),
#  ('TeamWales', 'loserOf', 'Match55'),
#  ('Match55', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match55', 'inCity', 'CityCrewe'),
#  ('Match55', 'inCountry', 'CountryEngland'),
#  ('Match55', 'isNeutral', 'False'),
#  ('Match55', 'atYear', '1888'),
#  ('Match55', 'homeScores', 5),
#  ('Match55', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match56'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match56'),
#  ('TeamWales', 'winnerOf', 'Match56'),
#  ('TeamNorthernIreland', 'loserOf', 'Match56'),
#  ('Match56', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match56', 'inCity', 'CityWrexham'),
#  ('Match56', 'inCountry', 'CountryWales'),
#  ('Match56', 'isNeutral', 'False'),
#  ('Match56', 'atYear', '1888'),
#  ('Match56', 'homeScores', 5),
#  ('Match56', 'awayScores', 0),
#  ('TeamScotland', 'isHomeTeamIn', 'Match57'),
#  ('TeamWales', 'isAwayTeamIn', 'Match57'),
#  ('TeamScotland', 'winnerOf', 'Match57'),
#  ('TeamWales', 'loserOf', 'Match57'),
#  ('Match57', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match57', 'inCity', 'CityEdinburgh'),
#  ('Match57', 'inCountry', 'CountryScotland'),
#  ('Match57', 'isNeutral', 'False'),
#  ('Match57', 'atYear', '1888'),
#  ('Match57', 'homeScores', 5),
#  ('Match57', 'awayScores', 1),
#  ('TeamScotland', 'isHomeTeamIn', 'Match58'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match58'),
#  ('TeamScotland', 'loserOf', 'Match58'),
#  ('TeamEngland', 'winnerOf', 'Match58'),
#  ('Match58', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match58', 'inCity', 'CityGlasgow'),
#  ('Match58', 'inCountry', 'CountryScotland'),
#  ('Match58', 'isNeutral', 'False'),
#  ('Match58', 'atYear', '1888'),
#  ('Match58', 'homeScores', 0),
#  ('Match58', 'awayScores', 5),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match59'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match59'),
#  ('TeamNorthernIreland', 'loserOf', 'Match59'),
#  ('TeamScotland', 'winnerOf', 'Match59'),
#  ('Match59', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match59', 'inCity', 'CityBelfast'),
#  ('Match59', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match59', 'isNeutral', 'False'),
#  ('Match59', 'atYear', '1888'),
#  ('Match59', 'homeScores', 2),
#  ('Match59', 'awayScores', 5),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match60'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match60'),
#  ('TeamNorthernIreland', 'loserOf', 'Match60'),
#  ('TeamEngland', 'winnerOf', 'Match60'),
#  ('Match60', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match60', 'inCity', 'CityBelfast'),
#  ('Match60', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match60', 'isNeutral', 'False'),
#  ('Match60', 'atYear', '1888'),
#  ('Match60', 'homeScores', 1),
#  ('Match60', 'awayScores', 5),
#  ('TeamScotland', 'isHomeTeamIn', 'Match61'),
#  ('TeamCanada', 'isAwayTeamIn', 'Match61'),
#  ('TeamScotland', 'winnerOf', 'Match61'),
#  ('TeamCanada', 'loserOf', 'Match61'),
#  ('Match61', 'inTournament', 'TournamentFriendly'),
#  ('Match61', 'inCity', 'CityGlasgow'),
#  ('Match61', 'inCountry', 'CountryScotland'),
#  ('Match61', 'isNeutral', 'False'),
#  ('Match61', 'atYear', '1888'),
#  ('Match61', 'homeScores', 4),
#  ('Match61', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match62'),
#  ('TeamWales', 'isAwayTeamIn', 'Match62'),
#  ('TeamEngland', 'winnerOf', 'Match62'),
#  ('TeamWales', 'loserOf', 'Match62'),
#  ('Match62', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match62', 'inCity', 'CityStoke-On-Trent'),
#  ('Match62', 'inCountry', 'CountryEngland'),
#  ('Match62', 'isNeutral', 'False'),
#  ('Match62', 'atYear', '1889'),
#  ('Match62', 'homeScores', 4),
#  ('Match62', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match63'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match63'),
#  ('TeamEngland', 'winnerOf', 'Match63'),
#  ('TeamNorthernIreland', 'loserOf', 'Match63'),
#  ('Match63', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match63', 'inCity', 'CityLiverpool'),
#  ('Match63', 'inCountry', 'CountryEngland'),
#  ('Match63', 'isNeutral', 'False'),
#  ('Match63', 'atYear', '1889'),
#  ('Match63', 'homeScores', 5),
#  ('Match63', 'awayScores', 1),
#  ('TeamScotland', 'isHomeTeamIn', 'Match64'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match64'),
#  ('TeamScotland', 'winnerOf', 'Match64'),
#  ('TeamNorthernIreland', 'loserOf', 'Match64'),
#  ('Match64', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match64', 'inCity', 'CityGlasgow'),
#  ('Match64', 'inCountry', 'CountryScotland'),
#  ('Match64', 'isNeutral', 'False'),
#  ('Match64', 'atYear', '1889'),
#  ('Match64', 'homeScores', 5),
#  ('Match64', 'awayScores', 0),
#  ('TeamEngland', 'isHomeTeamIn', 'Match65'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match65'),
#  ('TeamEngland', 'loserOf', 'Match65'),
#  ('TeamScotland', 'winnerOf', 'Match65'),
#  ('Match65', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match65', 'inCity', 'CityLondon'),
#  ('Match65', 'inCountry', 'CountryEngland'),
#  ('Match65', 'isNeutral', 'False'),
#  ('Match65', 'atYear', '1889'),
#  ('Match65', 'homeScores', 2),
#  ('Match65', 'awayScores', 3),
#  ('TeamWales', 'isHomeTeamIn', 'Match66'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match66'),
#  ('TeamWales', 'draws', 'Match66'),
#  ('TeamScotland', 'draws', 'Match66'),
#  ('Match66', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match66', 'inCity', 'CityWrexham'),
#  ('Match66', 'inCountry', 'CountryWales'),
#  ('Match66', 'isNeutral', 'False'),
#  ('Match66', 'atYear', '1889'),
#  ('Match66', 'homeScores', 0),
#  ('Match66', 'awayScores', 0),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match67'),
#  ('TeamWales', 'isAwayTeamIn', 'Match67'),
#  ('TeamNorthernIreland', 'loserOf', 'Match67'),
#  ('TeamWales', 'winnerOf', 'Match67'),
#  ('Match67', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match67', 'inCity', 'CityBelfast'),
#  ('Match67', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match67', 'isNeutral', 'False'),
#  ('Match67', 'atYear', '1889'),
#  ('Match67', 'homeScores', 1),
#  ('Match67', 'awayScores', 3),
#  ('TeamWales', 'isHomeTeamIn', 'Match68'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match68'),
#  ('TeamWales', 'winnerOf', 'Match68'),
#  ('TeamNorthernIreland', 'loserOf', 'Match68'),
#  ('Match68', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match68', 'inCity', 'CityShrewsbury'),
#  ('Match68', 'inCountry', 'CountryEngland'),
#  ('Match68', 'isNeutral', 'True'),
#  ('Match68', 'atYear', '1890'),
#  ('Match68', 'homeScores', 5),
#  ('Match68', 'awayScores', 2),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match69'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match69'),
#  ('TeamNorthernIreland', 'loserOf', 'Match69'),
#  ('TeamEngland', 'winnerOf', 'Match69'),
#  ('Match69', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match69', 'inCity', 'CityBelfast'),
#  ('Match69', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match69', 'isNeutral', 'False'),
#  ('Match69', 'atYear', '1890'),
#  ('Match69', 'homeScores', 1),
#  ('Match69', 'awayScores', 5),
#  ('TeamWales', 'isHomeTeamIn', 'Match70'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match70'),
#  ('TeamWales', 'loserOf', 'Match70'),
#  ('TeamEngland', 'winnerOf', 'Match70'),
#  ('Match70', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match70', 'inCity', 'CityWrexham'),
#  ('Match70', 'inCountry', 'CountryWales'),
#  ('Match70', 'isNeutral', 'False'),
#  ('Match70', 'atYear', '1890'),
#  ('Match70', 'homeScores', 1),
#  ('Match70', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match71'),
#  ('TeamWales', 'isAwayTeamIn', 'Match71'),
#  ('TeamScotland', 'winnerOf', 'Match71'),
#  ('TeamWales', 'loserOf', 'Match71'),
#  ('Match71', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match71', 'inCity', 'CityPaisley'),
#  ('Match71', 'inCountry', 'CountryScotland'),
#  ('Match71', 'isNeutral', 'False'),
#  ('Match71', 'atYear', '1890'),
#  ('Match71', 'homeScores', 5),
#  ('Match71', 'awayScores', 0),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match72'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match72'),
#  ('TeamNorthernIreland', 'loserOf', 'Match72'),
#  ('TeamScotland', 'winnerOf', 'Match72'),
#  ('Match72', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match72', 'inCity', 'CityBelfast'),
#  ('Match72', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match72', 'isNeutral', 'False'),
#  ('Match72', 'atYear', '1890'),
#  ('Match72', 'homeScores', 1),
#  ('Match72', 'awayScores', 4),
#  ('TeamScotland', 'isHomeTeamIn', 'Match73'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match73'),
#  ('TeamScotland', 'draws', 'Match73'),
#  ('TeamEngland', 'draws', 'Match73'),
#  ('Match73', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match73', 'inCity', 'CityGlasgow'),
#  ('Match73', 'inCountry', 'CountryScotland'),
#  ('Match73', 'isNeutral', 'False'),
#  ('Match73', 'atYear', '1890'),
#  ('Match73', 'homeScores', 1),
#  ('Match73', 'awayScores', 1),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match74'),
#  ('TeamWales', 'isAwayTeamIn', 'Match74'),
#  ('TeamNorthernIreland', 'winnerOf', 'Match74'),
#  ('TeamWales', 'loserOf', 'Match74'),
#  ('Match74', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match74', 'inCity', 'CityBelfast'),
#  ('Match74', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match74', 'isNeutral', 'False'),
#  ('Match74', 'atYear', '1891'),
#  ('Match74', 'homeScores', 5),
#  ('Match74', 'awayScores', 2),
#  ('TeamEngland', 'isHomeTeamIn', 'Match75'),
#  ('TeamWales', 'isAwayTeamIn', 'Match75'),
#  ('TeamEngland', 'winnerOf', 'Match75'),
#  ('TeamWales', 'loserOf', 'Match75'),
#  ('Match75', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match75', 'inCity', 'CitySunderland'),
#  ('Match75', 'inCountry', 'CountryEngland'),
#  ('Match75', 'isNeutral', 'False'),
#  ('Match75', 'atYear', '1891'),
#  ('Match75', 'homeScores', 4),
#  ('Match75', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match76'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match76'),
#  ('TeamEngland', 'winnerOf', 'Match76'),
#  ('TeamNorthernIreland', 'loserOf', 'Match76'),
#  ('Match76', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match76', 'inCity', 'CityWolverhampton'),
#  ('Match76', 'inCountry', 'CountryEngland'),
#  ('Match76', 'isNeutral', 'False'),
#  ('Match76', 'atYear', '1891'),
#  ('Match76', 'homeScores', 5),
#  ('Match76', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match77'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match77'),
#  ('TeamWales', 'loserOf', 'Match77'),
#  ('TeamScotland', 'winnerOf', 'Match77'),
#  ('Match77', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match77', 'inCity', 'CityWrexham'),
#  ('Match77', 'inCountry', 'CountryWales'),
#  ('Match77', 'isNeutral', 'False'),
#  ('Match77', 'atYear', '1891'),
#  ('Match77', 'homeScores', 3),
#  ('Match77', 'awayScores', 4),
#  ('TeamScotland', 'isHomeTeamIn', 'Match78'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match78'),
#  ('TeamScotland', 'winnerOf', 'Match78'),
#  ('TeamNorthernIreland', 'loserOf', 'Match78'),
#  ('Match78', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match78', 'inCity', 'CityGlasgow'),
#  ('Match78', 'inCountry', 'CountryScotland'),
#  ('Match78', 'isNeutral', 'False'),
#  ('Match78', 'atYear', '1891'),
#  ('Match78', 'homeScores', 2),
#  ('Match78', 'awayScores', 1),
#  ('TeamWales', 'isHomeTeamIn', 'Match79'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match79'),
#  ('TeamWales', 'draws', 'Match79'),
#  ('TeamNorthernIreland', 'draws', 'Match79'),
#  ('Match79', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match79', 'inCity', 'CityBangor'),
#  ('Match79', 'inCountry', 'CountryWales'),
#  ('Match79', 'isNeutral', 'False'),
#  ('Match79', 'atYear', '1892'),
#  ('Match79', 'homeScores', 1),
#  ('Match79', 'awayScores', 1),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match80'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match80'),
#  ('TeamNorthernIreland', 'loserOf', 'Match80'),
#  ('TeamEngland', 'winnerOf', 'Match80'),
#  ('Match80', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match80', 'inCity', 'CityBelfast'),
#  ('Match80', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match80', 'isNeutral', 'False'),
#  ('Match80', 'atYear', '1892'),
#  ('Match80', 'homeScores', 0),
#  ('Match80', 'awayScores', 2),
#  ('TeamWales', 'isHomeTeamIn', 'Match81'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match81'),
#  ('TeamWales', 'loserOf', 'Match81'),
#  ('TeamEngland', 'winnerOf', 'Match81'),
#  ('Match81', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match81', 'inCity', 'CityWrexham'),
#  ('Match81', 'inCountry', 'CountryWales'),
#  ('Match81', 'isNeutral', 'False'),
#  ('Match81', 'atYear', '1892'),
#  ('Match81', 'homeScores', 0),
#  ('Match81', 'awayScores', 2),
#  ('TeamNorthernIreland', 'isHomeTeamIn', 'Match82'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match82'),
#  ('TeamNorthernIreland', 'loserOf', 'Match82'),
#  ('TeamScotland', 'winnerOf', 'Match82'),
#  ('Match82', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match82', 'inCity', 'CityBelfast'),
#  ('Match82', 'inCountry', 'CountryRepublicOfIreland'),
#  ('Match82', 'isNeutral', 'False'),
#  ('Match82', 'atYear', '1892'),
#  ('Match82', 'homeScores', 2),
#  ('Match82', 'awayScores', 3),
#  ('TeamScotland', 'isHomeTeamIn', 'Match83'),
#  ('TeamWales', 'isAwayTeamIn', 'Match83'),
#  ('TeamScotland', 'winnerOf', 'Match83'),
#  ('TeamWales', 'loserOf', 'Match83'),
#  ('Match83', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match83', 'inCity', 'CityEdinburgh'),
#  ('Match83', 'inCountry', 'CountryScotland'),
#  ('Match83', 'isNeutral', 'False'),
#  ('Match83', 'atYear', '1892'),
#  ('Match83', 'homeScores', 5),
#  ('Match83', 'awayScores', 1),
#  ('TeamScotland', 'isHomeTeamIn', 'Match84'),
#  ('TeamEngland', 'isAwayTeamIn', 'Match84'),
#  ('TeamScotland', 'loserOf', 'Match84'),
#  ('TeamEngland', 'winnerOf', 'Match84'),
#  ('Match84', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match84', 'inCity', 'CityGlasgow'),
#  ('Match84', 'inCountry', 'CountryScotland'),
#  ('Match84', 'isNeutral', 'False'),
#  ('Match84', 'atYear', '1892'),
#  ('Match84', 'homeScores', 1),
#  ('Match84', 'awayScores', 4),
#  ('TeamEngland', 'isHomeTeamIn', 'Match85'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match85'),
#  ('TeamEngland', 'winnerOf', 'Match85'),
#  ('TeamNorthernIreland', 'loserOf', 'Match85'),
#  ('Match85', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match85', 'inCity', 'CityBirmingham'),
#  ('Match85', 'inCountry', 'CountryEngland'),
#  ('Match85', 'isNeutral', 'False'),
#  ('Match85', 'atYear', '1893'),
#  ('Match85', 'homeScores', 5),
#  ('Match85', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match86'),
#  ('TeamWales', 'isAwayTeamIn', 'Match86'),
#  ('TeamEngland', 'winnerOf', 'Match86'),
#  ('TeamWales', 'loserOf', 'Match86'),
#  ('Match86', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match86', 'inCity', 'CityStoke-On-Trent'),
#  ('Match86', 'inCountry', 'CountryEngland'),
#  ('Match86', 'isNeutral', 'False'),
#  ('Match86', 'atYear', '1893'),
#  ('Match86', 'homeScores', 5),
#  ('Match86', 'awayScores', 0),
#  ('TeamWales', 'isHomeTeamIn', 'Match87'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match87'),
#  ('TeamWales', 'loserOf', 'Match87'),
#  ('TeamScotland', 'winnerOf', 'Match87'),
#  ('Match87', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match87', 'inCity', 'CityWrexham'),
#  ('Match87', 'inCountry', 'CountryWales'),
#  ('Match87', 'isNeutral', 'False'),
#  ('Match87', 'atYear', '1893'),
#  ('Match87', 'homeScores', 0),
#  ('Match87', 'awayScores', 5),
#  ('TeamScotland', 'isHomeTeamIn', 'Match88'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match88'),
#  ('TeamScotland', 'winnerOf', 'Match88'),
#  ('TeamNorthernIreland', 'loserOf', 'Match88'),
#  ('Match88', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match88', 'inCity', 'CityGlasgow'),
#  ('Match88', 'inCountry', 'CountryScotland'),
#  ('Match88', 'isNeutral', 'False'),
#  ('Match88', 'atYear', '1893'),
#  ('Match88', 'homeScores', 5),
#  ('Match88', 'awayScores', 1),
#  ('TeamEngland', 'isHomeTeamIn', 'Match89'),
#  ('TeamScotland', 'isAwayTeamIn', 'Match89'),
#  ('TeamEngland', 'winnerOf', 'Match89'),
#  ('TeamScotland', 'loserOf', 'Match89'),
#  ('Match89', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match89', 'inCity', 'CityRichmond'),
#  ('Match89', 'inCountry', 'CountryEngland'),
#  ('Match89', 'isNeutral', 'False'),
#  ('Match89', 'atYear', '1893'),
#  ('Match89', 'homeScores', 5),
#  ('Match89', 'awayScores', 2),
#  ('TeamWales', 'isHomeTeamIn', 'Match90'),
#  ('TeamNorthernIreland', 'isAwayTeamIn', 'Match90'),
#  ('TeamWales', 'winnerOf', 'Match90'),
#  ('TeamNorthernIreland', 'loserOf', 'Match90'),
#  ('Match90', 'inTournament', 'TournamentBritishChampionship'),
#  ('Match90', 'inCity', 'CitySwansea'),
#  ('Match90', 'inCountry', 'CountryWales'),
#  ('Match90', 'isNeutral', 'False'),
#  ('Match90', 'atYear', '1894'),
#  ('Match90', 'homeScores', 4),
#  ...]

# %% [markdown]
# Note that we treat some literals (year, neutral match, home score, away score) as discrete entities and they will be part of the final knowledge graph used to generate the embeddings. We limit the number of score entities by clipping the score to be at most 5.

# %% [markdown]
# Below we can see visualise a subset of the graph related to the infamous [Maracanazo](https://en.wikipedia.org/wiki/Uruguay_v_Brazil_(1950_FIFA_World_Cup)):
#
#
# ![Football graph](https://drive.google.com/uc?id=1sN-Iil4xAKbQXICTl4YlVATqN0FfGpcr)

# %% [markdown]
# The whole graph related to this match can be summarised by the triples below:

# %%
triples_df = pd.DataFrame(triples, columns=["subject", "predicate", "object"])
triples_df[(triples_df.subject=="Match3129") | (triples_df.object=="Match3129")]
# Out:
#            subject     predicate                  object
# 34419   TeamBrazil  isHomeTeamIn               Match3129
# 34420  TeamUruguay  isAwayTeamIn               Match3129
# 34421   TeamBrazil       loserOf               Match3129
# 34422  TeamUruguay      winnerOf               Match3129
# 34423    Match3129  inTournament  TournamentFifaWorldCup
# 34424    Match3129        inCity        CityRioDeJaneiro
# 34425    Match3129     inCountry           CountryBrazil
# 34426    Match3129     isNeutral                   False
# 34427    Match3129        atYear                    1950
# 34428    Match3129    homeScores                       1
# 34429    Match3129    awayScores                       2

# %%
triples_df
# Out:
#              subject     predicate              object
# 0       TeamScotland  isHomeTeamIn              Match0
# 1        TeamEngland  isAwayTeamIn              Match0
# 2       TeamScotland         draws              Match0
# 3        TeamEngland         draws              Match0
# 4             Match0  inTournament  TournamentFriendly
# ...              ...           ...                 ...
# 392849    Match35713     inCountry        CountryQatar
# 392850    Match35713     isNeutral               False
# 392851    Match35713        atYear                2013
# 392852    Match35713    homeScores                   4
# 392853    Match35713    awayScores                   1
#
# [392854 rows x 3 columns]

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(triples_df, "subject", "object", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(triples_df[triples_df['predicate']=="isHomeTeamIn"], "subject", "object",  
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(triples_df[triples_df['predicate']=="atYear"], "subject", "object",  
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# ## Training knowledge graph embeddings
#
# We split our training dataset further into training and validation, where the new training set will be used to the knowledge embedding training and the validation set will be used in its evaluation. The test set will be used to evaluate the performance of the classification algorithm built on top of the embeddings.
#
# What differs from the standard method of randomly sampling N points to make up our validation set is that our data points are two entities linked by some relationship, and we need to take care to ensure that all entities are represented in train and validation sets by at least one triple.
#
# To accomplish this, AmpliGraph provides the [`train_test_split_no_unseen`](https://docs.ampligraph.org/en/latest/generated/ampligraph.evaluation.train_test_split_no_unseen.html#train-test-split-no-unseen) function.

# %%
from ampligraph.evaluation import train_test_split_no_unseen 

X_train, X_valid = train_test_split_no_unseen(np.array(triples), test_size=10000)

# %%
print('Train set size: ', X_train.shape)
print('Test set size: ', X_valid.shape)

# %% [markdown]
# AmpliGraph has implemented [several Knowledge Graph Embedding models](https://docs.ampligraph.org/en/latest/ampligraph.latent_features.html#knowledge-graph-embedding-models) (TransE, ComplEx, DistMult, HolE), but to begin with we're just going to use the [ComplEx](https://docs.ampligraph.org/en/latest/generated/ampligraph.latent_features.ComplEx.html#ampligraph.latent_features.ComplEx) model, which is known to bring state-of-the-art predictive power.
#
# The hyper-parameter choice was based on the [best results](https://docs.ampligraph.org/en/latest/experiments.html) we have found so far for the ComplEx model applied to some benchmark datasets used in the knowledge graph embeddings community. This tutorial does not cover [hyper-parameter tuning](https://docs.ampligraph.org/en/latest/examples.html#model-selection).

# %%
from ampligraph.latent_features import ComplEx

model = ComplEx(batches_count=50,
                epochs=300,
                k=100,
                eta=20,
                optimizer='adam', 
                optimizer_params={'lr':1e-4},
                loss='multiclass_nll',
                regularizer='LP', 
                regularizer_params={'p':3, 'lambda':1e-5}, 
                seed=0, 
                verbose=True)

# %% [markdown]
# Lets go through the parameters to understand what's going on:
#
# - **`batches_count`** : the number of batches in which the training set is split during the training loop. If you are having into low memory issues than settings this to a higher number may help.
# - **`epochs`** : the number of epochs to train the model for.
# - **`k`**: the dimensionality of the embedding space.
# - **`eta`** ($\\eta$) : the number of negative, or false triples that must be generated at training runtime for each positive, or true triple.
# - **`optimizer`** : the Adam optimizer, with a learning rate of 1e-4 set via the *optimizer_params* kwarg.
# - **`loss`** : pairwise loss, with a margin of 0.5 set via the *loss_params* kwarg.
# - **`regularizer`** : $L_p$ regularization with $p=3$, i.e. l3 regularization. $\\lambda$ = 1e-5, set via the *regularizer_params* kwarg.
# - **`seed`** : random seed, used for reproducibility.
# - **`verbose`** - displays a progress bar.

# %% [markdown]
# Training should take around 10 minutes on a modern GPU:

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

model.fit(X_train)

# %% [markdown]
# ## Evaluating knowledge embeddings
#
# AmpliGraph aims to follow scikit-learn's ease-of-use design philosophy and simplify everything down to **`fit`**, **`evaluate`**, and **`predict`** functions.
#
# However, there are some knowledge graph specific steps we must take to ensure our model can be trained and evaluated correctly. The first of these is defining the filter that will be used to ensure that no negative statements generated by the corruption procedure are actually positives. This is simply done by concatenating our train and test sets. Now when negative triples are generated by the corruption strategy, we can check that they aren't actually true statements.

# %%
filter_triples = np.concatenate((X_train, X_valid))

# %% [markdown]
# For this we'll use the `evaluate_performance` function:
#
# - **`X`** - the data to evaluate on. We're going to use our test set to evaluate.
# - **`model`** - the model we previously trained.
# - **`filter_triples`** - will filter out the false negatives generated by the corruption strategy.
# - **`use_default_protocol`** - specifies whether to use the default corruption protocol. If True, then subj and obj are corrupted separately during evaluation.
# - **`verbose`** - displays a progress bar.

# %%
from ampligraph.evaluation import evaluate_performance

ranks = evaluate_performance(X_valid,
                             model=model, 
                             filter_triples=filter_triples,
                             use_default_protocol=True,
                             verbose=True)

# %% [markdown]
# We're going to use the mrr_score (mean reciprocal rank) and hits_at_n_score functions.
#
# - **mrr_score**: The function computes the mean of the reciprocal of elements of a vector of rankings ranks.
# - **hits_at_n_score**: The function computes how many elements of a vector of rankings ranks make it to the top n positions.

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mr = mr_score(ranks)
mrr = mrr_score(ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))

# %% [markdown]
# We can interpret these results by stating that the model will rank the correct entity within the top-3 possibilities 29% of the time.
#
# By themselves, these metrics are not enough to conclude the usefulness of the embeddings in a downstream task, but they suggest that the embeddings have learned a reasonable representation enough to consider using them in more tasks.

# %% [markdown]
# ## Clustering and embedding visualization

# %% [markdown]
# To evaluate the subjective quality of the embeddings, we can visualise the embeddings on 2D space and also cluster them on the original space. We can compare the clustered embeddings with natural clusters, in this case the continent where the team is from, so that we have a ground truth to evaluate the clustering quality both qualitatively and quantitatively.
#
# Requirements:
#
# * seaborn
# * adjustText
# * incf.countryutils
#
# For seaborn and adjustText, simply install them with `pip install seaborn adjustText`.
#
# For incf.countryutils, do the following steps:
# ```bash
# git clone https://github.com/wyldebeast-wunderliebe/incf.countryutils.git
# cd incf.countryutils
# pip install .```

# %% [markdown]
# Run the following code to install requirements in colab environment

# %%
# %%capture
# !pip install seaborn adjustText
# !git clone https://github.com/wyldebeast-wunderliebe/incf.countryutils.git
# !pip install incf.countryutils/.

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from incf.countryutils import transformations
# %matplotlib inline

# %% [markdown]
# We create a map from the team ID (e.g. "TeamBrazil") to the team name (e.g. "Brazil") for visualization purposes.

# %%
id_to_name_map = {**dict(zip(df.home_team_id, df.home_team)), **dict(zip(df.away_team_id, df.away_team))}

# %% [markdown]
# We now create a dictionary with the embeddings of all teams:

# %%
teams = pd.concat((df.home_team_id[df["train"]], df.away_team_id[df["train"]])).unique()
team_embeddings = dict(zip(teams, model.get_embeddings(teams)))

# %% [markdown]
# We use PCA to project the embeddings from the 200 space into 2D space:

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in team_embeddings.values()]))

# %% [markdown]
# We will cluster the teams embeddings on its original 200-dimensional space using the `find_clusters` in our discovery API:

# %%
from ampligraph.discovery import find_clusters
from sklearn.cluster import KMeans

clustering_algorithm = KMeans(n_clusters=6, n_init=50, max_iter=500, random_state=0)
clusters = find_clusters(teams, model, clustering_algorithm, mode='entity')

# %% [markdown]
# This helper function uses the `incf.countryutils` library to translate country names to their corresponding continents.

# %%
def cn_to_ctn(country):
    try:
        return transformations.cn_to_ctn(id_to_name_map[country])
    except KeyError:
        return "unk"

# %% [markdown]
# This dataframe contains for each team their projected embeddings to 2D space via PCA, their continent and the KMeans cluster. This will be used alongisde Seaborn to make the visualizations.

# %%
plot_df = pd.DataFrame({"teams": teams, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "continent": pd.Series(teams).apply(cn_to_ctn),
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})

# %% [markdown]
# We plot the results on a 2D scatter plot, coloring the teams by the continent or cluster and also displaying some individual team names.
#
# We always display the names of the top 20 teams (according to [FIFA rankings](https://en.wikipedia.org/wiki/FIFA_World_Rankings)) and a random subset of the rest.

# %%
top20teams = ["TeamBelgium", "TeamFrance", "TeamBrazil", "TeamEngland", "TeamPortugal", "TeamCroatia", "TeamSpain", 
              "TeamUruguay", "TeamSwitzerland", "TeamDenmark", "TeamArgentina", "TeamGermany", "TeamColombia",
              "TeamItaly", "TeamNetherlands", "TeamChile", "TeamSweden", "TeamMexico", "TeamPoland", "TeamIran"]

def plot_clusters(hue):
    np.random.seed(0)
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df[plot_df.continent!="unk"], x="embedding1", y="embedding2", hue=hue)
    texts = []
    for i, point in plot_df.iterrows():
        if point["teams"] in top20teams or np.random.random() < 0.1:
            texts.append(plt.text(point['embedding1']+0.02, point['embedding2']+0.01, str(point["teams"])))
    adjust_text(texts)

# %% [markdown]
# The first visualisation of the 2D embeddings shows the natural geographical clusters (continents), which can be seen as a form of the ground truth:

# %%
plot_clusters("continent")

# %% [markdown]
# We can see above that the embeddings learned geographical similarities even though this information was not explicit on the original dataset.
#
# Now we plot the same 2D embeddings but with the clusters found by K-Means:

# %%
plot_clusters("cluster")

# %% [markdown]
# We can see that K-Means found very similar cluster to the natural geographical clusters by the continents. This shows that on the 200-dimensional embedding space, similar teams appear close together, which can be captured by a clustering algorithm.
#
# Our evaluation of the clusters can be more objective by using a metric such as the [adjusted Rand score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html), which varies from -1 to 1, where 0 is random labelling and 1 is a perfect match:

# %%
from sklearn import metrics
metrics.adjusted_rand_score(plot_df.continent, plot_df.cluster)

# %% [markdown]
# ## Classification
#
# We will use the knowledge embeddings to predict future matches as a classification problem.
#
# We can model it as a multiclass problem with three classes: home team wins, home team loses, draw.
#
# The embeddings are used directly as features to a XGBoost classifier.
#
# First we need to determine the target:

# %%
df["results"] = (df.home_score > df.away_score).astype(int) + \
                (df.home_score == df.away_score).astype(int)*2 + \
                (df.home_score < df.away_score).astype(int)*3 - 1

# %%
df.results.value_counts(normalize=True)

# %% [markdown]
# Now we create a function that extracts the features (knowledge embeddings for home and away teams) and the target for a particular subset of the dataset:

# %%
def get_features_target(mask):
    
    def get_embeddings(team):
        return team_embeddings.get(team, np.full(200, np.nan))
    
    X = np.hstack((np.vstack(df[mask].home_team_id.apply(get_embeddings).values),
                   np.vstack(df[mask].away_team_id.apply(get_embeddings).values)))
    y = df[mask].results.values
    return X, y

# %%
clf_X_train, y_train = get_features_target((df["train"]))
clf_X_test, y_test = get_features_target((~df["train"]))

# %%
clf_X_train.shape, clf_X_test.shape

# %% [markdown]
# Note that we have 200 features by team because the ComplEx model uses imaginary and real number for its embeddings, so we have twice as many parameters as defined by `k=100` in its model definition.
#
# We also have some missing information from the embeddings of the entities (i.e. teams) that only appear in the test set, which are unlikely to be correctly classified:

# %%
np.isnan(clf_X_test).sum()/clf_X_test.shape[1]

# %% [markdown]
# First install xgboost with `pip install xgboost`.

# %%
#%%capture
#!pip install xgboost
from xgboost import XGBClassifier

# %% [markdown]
# Create a multiclass model with 500 estimators:

# %%
clf_model = XGBClassifier(n_estimators=500, max_depth=5, objective="multi:softmax")

# %% [markdown]
# Fit the model using all of the training samples:

# %%
clf_model.fit(clf_X_train, y_train)

# %% [markdown]
# The baseline accuracy for this problem is 47%, as that is the frequency of the most frequent class (home team wins):

# %%
df[~df["train"]].results.value_counts(normalize=True)

# %%
metrics.accuracy_score(y_test, clf_model.predict(clf_X_test))

# %% [markdown]
# In conclusion, while the baseline for this classification problem was 47%, with just the knowledge embeddings alone we were able to build a classifier that achieves **54%** accuracy.
#
#
#
# ---
